# %%
import os
os.chdir("..")
assert 'PromptDataExtract' in os.getcwd()

# %%
# Load settings
from backend import sett, postgres
from backend.utils.frame import Frame
sett.load_settings()
postgres.load_settings()
# Out:
# Load OK: settings.yaml

# %%
# Connect to database
db = postgres.connect('polylet')
# Out:
#       -- postgres_ SSH tunnel established.
# NOTE  -- postgres_ Connected to PostGres DB: polylet (took 0.048 s)

# %%
import pandas as pd
import matplotlib.pyplot as plt
try:
    plt.style.use("PromptDataExtraction/notebooks/matplotlib.mplstyle")
except:
    try:
        plt.style.use("~/matplotlib.mplstyle")
    except: pass

# %%
def execute(sql, **kwargs) -> pd.DataFrame:
    """ Query the database using raw sql.
        Return a pandas dataframe containing the results.
    """
    results = postgres.raw_sql(sql, kwargs)
    if not results:
        return None
    return pd.DataFrame.from_records(results, columns=results[0]._fields)

# %% [markdown]
# # Property Specific vs. General

# %%
# Methods IDs for property specific similar GPT pipeline.
gpt_similar_id_name = {
    164: 'glass transition temperature',
    171: 'melting temperature',
    155: 'thermal decomposition temperature',
    169: 'thermal conductivity',
    174: 'tensile strength',
    159: 'youngs modulus',
    130: 'compressive strength', 
    133: 'elongation at break',
    127: 'flexural strength',
    172: 'impact strength',
    157: 'ion exchange capacity',
    163: 'ionic conductivity',
    156: 'water contact angle',
    129: 'dielectric constant',
    134: 'density',
    131:  'bandgap',
    158: 'limiting oxygen index',
    170: 'hardness',
    173: 'lower critical solution temperature',
    166: 'upper critical solution temperature',
    132: 'CO_{2} permeability',
    167: 'O_{2} permeability',
    168: 'H_{2} permeability',
    128: 'crystallization temperature', 
    162: 'refractive index', 
    161: 'water uptake', 
    160: 'swelling degree', 
    165: 'methanol permeability'    
}

# %%
# All extracted properties by the P-GPT pipeline.
propnames = []
for _id, _item in gpt_similar_id_name.items():
    # print(_item)
    rows = postgres.raw_sql("""
                SELECT DISTINCT(ep.entity_name) FROM extracted_properties ep
                WHERE ep.method_id = :mid""", mid = _id)
    for row in rows:
        propnames.append(row.entity_name.lower())
propnames = list(set(propnames))
propnames = sorted(propnames)

# %%
print("Properties extracted by the property specific pipeline:", len(propnames))
propnames
# Out:
# Properties extracted by the property specific pipeline: 911
# ['%-elongation at break',
#  '%coverage',
#  '%χc',
#  '0-1 transition',
#  '0-2 transition',
#  '1% mass loss temperature',
#  '1% weight loss temperature',
#  '1-0 transition',
#  '10 % weight loss temperature',
#  '10 wt % weight loss temperature',
#  '10% decomposition temperature',
#  '10% degradation temperature',
#  '10% thermal decomposition temperature',
#  '10% weight loss temperature',
#  '10% weight-loss temperature',
#  '2-0 transition',
#  '20% weight loss decomposition temperature',
#  '5 wt % decomposition temperature',
#  '5% decomposition temperature',
#  '5% weight loss temperature',
#  '5% weight loss temperature (t5%)',
#  '50% cp change during vitrification',
#  '50% weight loss decomposition temperature',
#  '50% weight loss temperature',
#  'abs max',
#  'abs onset',
#  'absorption band',
#  'absorption band edges',
#  'absorption bands',
#  'absorption coefficient',
#  'absorption edge',
#  'absorption edge optical band gap',
#  'absorption maxima',
#  'absorption maximum',
#  'absorption maximum in solution',
#  'absorption maximum red-shift',
#  'absorption maximum wavelength',
#  'absorption onset',
#  'absorption onset value',
#  'absorption peak',
#  'absorption peaks in film',
#  'absorption peaks in solution',
#  'absorption profile',
#  'absorption range',
#  'absorption spectra',
#  'absorption spectrum',
#  'acid value',
#  'activation energy',
#  'active area',
#  'active layer thickness',
#  'adsorbed layer thickness',
#  'adsorption density',
#  'advancing contact angle',
#  'advancing water contact angle',
#  'aggregation transition',
#  'aggregation transition temperature',
#  'alpha',
#  'ambipolar charge transport',
#  'amount',
#  'annealing temperature',
#  'anodic peak',
#  'anodic peak current-density',
#  'apparent density',
#  'apparent viscosity',
#  'areal capacitance',
#  'average degree of polymerization',
#  'average hole volume',
#  'average m_w',
#  'average molecular weight of chain',
#  'average size',
#  'average size for a dry globule',
#  'band gap',
#  'band gap energy',
#  'band-gap',
#  'bandgap',
#  'bandgap (cyclic voltammetry)',
#  'bandgap (uv-vis absorption)',
#  'bandgap energy',
#  'bandgap values',
#  'barrier height',
#  'bending strength',
#  'binding ratio',
#  'blend ratio',
#  'bound water content',
#  'breakdown strength',
#  'breaking stress',
#  'breaking tensile stress',
#  'brightness',
#  'brightness enhancement',
#  'bulk density',
#  'calculated electrochemical band gap',
#  'calculated value',
#  'capacitance',
#  'capacitance retention',
#  'capacity',
#  'capacity retention',
#  'carrier density',
#  'cathodic peak',
#  'ced',
#  'ceiling temperature',
#  'cell capacitance',
#  'cell densities',
#  'cell density',
#  'cell size',
#  'cell sizes',
#  'ch2/co ratio',
#  'channel length',
#  'channel width',
#  'char at 1000 °c',
#  'char residue at 700 °c',
#  'char yield',
#  'char yield at 800 °c',
#  'char yield at 800 °c in nitrogen',
#  'char yields',
#  'char yields at 600 °c',
#  'charge density',
#  'charge per unit area after 500 cycles',
#  'charge per unit area at 1st cycle',
#  'charge recombination lifetime',
#  'charge separation',
#  'charge transfer resistance',
#  'charge transport',
#  'chemical reactions',
#  'cie coordinate',
#  'cie coordinates',
#  'clearing temperature',
#  'cloud point',
#  'co2 permeability',
#  'co2/ch4 selectivity',
#  'cold crystallization',
#  'cold crystallization temperature',
#  'cold crystallization temperature (tcc)',
#  'color contrast',
#  'coloration efficiency',
#  'coloration/decoloration rates',
#  'complete chemical decomposition temperature',
#  'compressive modulus',
#  'compressive strength',
#  'compressive stress',
#  'concentration',
#  'conductivity',
#  'conjugation length',
#  'contact angle',
#  'contact angle with water',
#  'core tg',
#  'corona treatment',
#  'corrosion resistance',
#  'coulombic efficiency',
#  'cross-sectional area',
#  'crosslink density',
#  'crosslink density ratio to sibu',
#  'crystal melting temperature',
#  'crystal orientation transition temperature',
#  'crystalline content',
#  'crystalline melting point',
#  'crystallinity',
#  'crystallization exothermic peak',
#  'crystallization temperature',
#  'ct band red-shift',
#  'cte',
#  'curing peak',
#  'current',
#  'current bump voltage range',
#  'current density',
#  'current efficiency',
#  'cut-off wavelength',
#  'cycle performance retention',
#  'cycling stability',
#  'd n /d c',
#  'd/a ratio',
#  'dark current density',
#  'dc breakdown strength',
#  'decomposition inhibition',
#  'decomposition temperature',
#  'decomposition temperature (td)',
#  'decomposition temperature (tga_-5%)',
#  'decomposition temperature at 5 wt % weight loss',
#  'defect density',
#  'degradation temperature',
#  'density',
#  'density of traps',
#  'device efficiency',
#  'diameter',
#  'dielectric constant',
#  'dielectric constants',
#  'dielectric loss',
#  'dielectric strength',
#  'differential refractive index',
#  'diffraction efficiency',
#  'diffusion coefficient',
#  'dihedral angle',
#  'dihedral angle (conjugated backbone and side-chain thienyl moieties)',
#  'dihedral angle (thiophene units and fused-thiophene rings)',
#  'dimensional stability',
#  'dio concentration',
#  'dipole moment',
#  'dipole moment density',
#  'dipole strength',
#  'dipole switching percentage',
#  'direct band gap',
#  'direct band gap energy',
#  'direct optical band gap',
#  'discharge capacity',
#  'discharge energy density',
#  'discharge plateaus',
#  'discharged energy density',
#  'dissipation factor',
#  'dn',
#  'doping concentration',
#  'double layer capacitance',
#  'double melting peak',
#  'dri increment',
#  'driving current density',
#  'dtg/dp',
#  'dtm/dp',
#  'dynamic tg',
#  'e',
#  'e^{opt}_{g}',
#  'e_cal_g',
#  'e_g',
#  'e_homo',
#  'e_loss',
#  'e_lumo',
#  'e_onsetox',
#  'e_opt_g',
#  'e_t',
#  'e_{g}^{opt}',
#  'ea',
#  'ea σdc',
#  'eb',
#  'eecg',
#  'efficiency',
#  'eg',
#  'eg (calculated)',
#  'eg (experimental)',
#  'eg opt',
#  'eg_ec',
#  'eg_eff',
#  'eg_ele',
#  'eg_op',
#  'eg_opt',
#  'egelec',
#  'egopt',
#  'el emissive bands',
#  'el external quantum efficiency',
#  'el maxima',
#  'el maximum',
#  'el spectra maxima',
#  'elastic modulus',
#  'elec_bandgap',
#  'electric field intensity',
#  'electrical band gap energy',
#  'electrical conductivity',
#  'electrochemical band gap',
#  'electrochemical band gap (eg^ec)',
#  'electrochemical bandgap',
#  'electrochemical bandgap value',
#  'electrochemical capacity',
#  'electrochemical energy bandgap',
#  'electrochemical energy gap',
#  'electrochemical stability',
#  'electrochemically surface area',
#  'electron affinity',
#  'electron affinity (ea)',
#  'electron affinity (lumo level)',
#  'electron affinity values',
#  'electron density',
#  'electron mobility',
#  'electronic band gap',
#  'electronic band gap (eg)',
#  'electronic energy gap',
#  'elongation',
#  'elongation at break',
#  'elongation at breaking point',
#  'elongation-at-break',
#  'eloss',
#  'emission maxima',
#  'emission maximum wavelength',
#  'endothermic peaks',
#  'endothermic shift',
#  'endothermic transition temperature',
#  'energy (et)',
#  'energy band gap',
#  'energy bandgap',
#  'energy density',
#  'energy gap (eg)',
#  'entanglement density',
#  'enthalpy',
#  'eo coefficient',
#  'eo coefficient (γ_{33})',
#  'eonsetox',
#  'eoptg',
#  'eqe',
#  'eqe enhancement',
#  'eqe peak',
#  'eqe value',
#  'equilibrium melting point',
#  'equilibrium melting temperature',
#  'equilibrium monomer concentration',
#  'esr',
#  'et',
#  'excitation energy',
#  'exotherm temperature',
#  'exothermic peak temperature',
#  'exothermic phenomenon temperature',
#  'experimental band gap',
#  'experimental optical band gap',
#  'external quantum efficiency',
#  'f',
#  'ff',
#  'ff improvement',
#  'ff minimum',
#  'fill factor',
#  'fill factor (ff)',
#  'film thickness',
#  'first charge injection voltage',
#  'first degradation stage temperature',
#  'flatband potential',
#  'flexural modulus',
#  'flexural strength',
#  'fracture stress',
#  'free carrier concentration',
#  'g',
#  'g/d ratio',
#  'gas absorption',
#  'glass transition',
#  'glass transition of the crystal',
#  'glass transition temperature',
#  'glass transition temperature (tg)',
#  'glass-to-rubber transition temperature',
#  'glass-transition temperature',
#  'glass-transition temperature (tg)',
#  'gmax',
#  'gravimetric capacitance',
#  'gravimetric energy density',
#  'h',
#  'h+ ion conductivity',
#  'h2 evolution rate',
#  'ha',
#  'hardness',
#  'hc∞',
#  'heat of combustion',
#  'highest occupied molecular orbital energy',
#  'hoco stabilization',
#  'hole density',
#  'hole mobility',
#  'homo',
#  'homo binding energy',
#  'homo energy',
#  'homo energy level',
#  'homo energy level (e_homo)',
#  'homo energy levels',
#  'homo level',
#  'homo level rise',
#  'homo value',
#  'homo-lumo bandgap',
#  'homo-lumo gap',
#  'homo-lumo offset',
#  'homo/lumo levels',
#  'hrc',
#  'ht-ht configuration',
#  'humidity level',
#  'hydrophobicity',
#  'hydroxide ion conductivity',
#  'hydroxyl density',
#  'hysteresis losses',
#  'i_{p}',
#  'idt',
#  'iec',
#  'iec_nmr',
#  'illumination intensity',
#  'ilss',
#  'impact strength',
#  'impurities',
#  'in phase boundary',
#  'increase in signal',
#  'increase in t_{g}',
#  'increase in tg compared with noncyclic analog poly (ethylene carbonate)',
#  'indirect band gap',
#  'indirect band gap energy',
#  'initial decomposition temperature',
#  'initial decomposition temperature (idt)',
#  'initial degradation temperature',
#  'initial thermal decomposition temperature',
#  'initial thermal degradation temperature',
#  'integral current density',
#  'intensity',
#  'interface states density',
#  'interlaminar shear strength',
#  'internal cell size',
#  'intrinsic viscosity',
#  'iodine value',
#  'ion exchange capacity',
#  'ion-exchange capacity',
#  'ionic conductivity',
#  'ionization potential',
#  'ionization potential (homo level)',
#  'ionization potential (ip)',
#  'ionization potential values',
#  'ip',
#  'ipce',
#  'isotropic temperature',
#  'isotropization temperature',
#  'j_ph',
#  'j_sc',
#  'j_sc decrease',
#  'j_sc improvement',
#  'j_sc increase',
#  'j_sc values',
#  'j_{sc}',
#  'jph/jsat',
#  'jph/jsat ratio',
#  'jsat',
#  'jsc',
#  'jsc_eqe',
#  'k',
#  'k values',
#  'kx',
#  'kz',
#  'lc transition temperature',
#  'lcst',
#  'le',
#  'length of repeat unit',
#  'length scale',
#  'lifetime',
#  'ligand based reduction',
#  'ligand centered reductions',
#  'limiting oxygen index',
#  'liquid crystal-isotropization temperature',
#  'loading density of chromophores',
#  'loi',
#  'loi value',
#  'lomo energy level',
#  'loss',
#  'lower critical solution temperature',
#  'lowest unoccupied molecular orbital energy',
#  'luco stabilization',
#  'luminance',
#  'luminance efficiency',
#  'luminescence',
#  'luminescent efficiency',
#  'luminous efficiency',
#  'lumo',
#  'lumo energy',
#  'lumo energy level',
#  'lumo energy level (e_lumo)',
#  'lumo level',
#  'lumo offset',
#  'm',
#  'mass density',
#  'mass loss',
#  'mass loss rate',
#  'maximal water adsorption',
#  'maximal water uptake',
#  'maximum absorption coefficient',
#  'maximum absorption peak',
#  'maximum brightness',
#  'maximum degradation temperature',
#  'maximum derivative of weight loss',
#  'maximum elongation at break',
#  'maximum eqe',
#  'maximum luminance',
#  'maximum luminous efficiency',
#  'maximum power efficiency',
#  'maximum service temperature',
#  'maximum-rate degradation temperature',
#  'mean-field interaction parameter',
#  'melt transition temperature',
#  'melting',
#  'melting peak',
#  'melting peak temperature',
#  'melting point',
#  'melting point (tm)',
#  'melting point of crystalline domains',
#  'melting points',
#  'melting temperature',
#  'melting temperature (tm)',
#  'melting transition',
#  'melting transition temperature',
#  'melting zone start temperature',
#  'melting zone width',
#  'methanol permeability',
#  'microgel size',
#  'microhardness',
#  'midpoint discharging voltage',
#  'minimum reduction of optical energy gap',
#  'mn',
#  'mobility',
#  'modulus',
#  'moisture content',
#  'molar density',
#  'molar mass',
#  'molar volume',
#  'molecular weight',
#  'molecular weights',
#  'monomer oxidation potential',
#  'mp',
#  'mu/mu',
#  'mv',
#  'mw',
#  'mw/mn',
#  'n value',
#  'n_{d}^{23}',
#  'nc',
#  'nd^{23}',
#  'nh',
#  "nh'",
#  'nhg',
#  'nlo response',
#  'nominal pore size',
#  'none',
#  'nonlinear optical coefficient',
#  'nucleating activity',
#  'nucleation constant',
#  'number of holes',
#  'number-average molecular weight',
#  'o2 permeability',
#  'oca',
#  'oh^{-} conductivity',
#  'on-set decomposition temperature',
#  'on-site decomposition temperature',
#  'onset decomposition temperature',
#  'onset degradation temperature',
#  'onset of absorption',
#  'onset of absorption in thin films',
#  'onset of cold crystallization',
#  'onset of decomposition',
#  'onset of decomposition temperature',
#  'onset of degradation at 5% weight loss',
#  'onset of thermal degradation',
#  'onset of weight loss',
#  'onset oxidation potential',
#  'onset reduction potential',
#  'onset temperature for thermal decomposition',
#  'onset temperature of crystallinity and tm changes',
#  'onset temperature of decomposition',
#  'onset temperature of degradation',
#  'onset temperature of weight loss',
#  'open circuit voltage',
#  'open-circuit voltage',
#  'open-circuit voltage (v_{oc})',
#  'optical band gap',
#  'optical band gap energy',
#  'optical band gap in solution',
#  'optical band gap in thin film',
#  'optical band gaps',
#  'optical band-gap',
#  'optical bandgap',
#  'optical bandgap energy',
#  'optical contrast',
#  'optical contrast at 1500 nm',
#  'optical contrast at 1560 nm',
#  'optical contrast at 570 nm',
#  'optical contrast at 580 nm',
#  'optical contrast at 850 nm',
#  'optical densities',
#  'optical density (od)',
#  'optical dielectric constant',
#  'optical eg',
#  'optical energy gap',
#  'optical power',
#  'optical-band-gap energy',
#  'optimal',
#  'order-disorder transition temperature',
#  'overall power conversion efficiency (pce)',
#  'overpotential',
#  'oxidation couple',
#  'oxidation onset potential',
#  'oxidation potential',
#  'oxygen permeability',
#  'oxygen permeability coefficient',
#  'p',
#  'p/pdip,theory',
#  'p_{ch4}',
#  'p_{h2}',
#  'p_{he}',
#  'p_{n2}',
#  'paracrystalline lattice distortions',
#  'pc',
#  'pce',
#  'pce enhancement',
#  'pd',
#  'pdip,theory',
#  'pdiss',
#  'peak power density',
#  'peak temperature',
#  'peak temperature of cationic ring-opening polymerization',
#  'peak water sorption',
#  'pec',
#  'pencil hardness',
#  'permeability',
#  'permittivity',
#  'phase transition temperature',
#  'photo-current density',
#  'photoconductivity',
#  'photocurrent density',
#  'photocurrent density difference',
#  'photons captured',
#  'phrr',
#  'pka',
#  'pl emission peak',
#  'pl maxima',
#  'pl quantum yield',
#  'pm',
#  'polycarbonate t_{g}',
#  'polydispersity',
#  'polydispersity index',
#  'polydispersity index (pdi)',
#  'polymerization temperature range',
#  'pore size',
#  'pore size distribution',
#  'power conversion efficiency',
#  'power density',
#  'power efficiency',
#  'pressure',
#  'primary cell size',
#  'proton conductivity',
#  'proton_density',
#  'puncture strength',
#  'pv performances',
#  'pwp',
#  'quality factor',
#  'quantum efficiency',
#  'quasi-reversible peak',
#  'qwe',
#  'r',
#  'radii',
#  'radius of gyration',
#  'range',
#  'ratio',
#  'rc',
#  'reaction peak',
#  'receding contact angle',
#  'recovery efficiency',
#  'recovery temperature',
#  'recovery temperature range',
#  'recrystallization temperature',
#  'red shift',
#  'redox couple',
#  'redox peak',
#  'reduction potential',
#  'reduction potential onset',
#  'reflector range',
#  'refractive index',
#  'refractive index increment',
#  'regioirregular configuration',
#  'regioregular configuration',
#  'rejection',
#  'relative permittivity',
#  'reported value',
#  'residual',
#  'residual mass',
#  'residual mass at 800 °c',
#  'residual weight percentage',
#  'residue',
#  'residue at 900 °c',
#  'residue char at 700 °c',
#  'residue solvent content',
#  'residue weight fraction',
#  'resilience',
#  'resistivity',
#  'reversible capacities',
#  'reversible capacity',
#  'reversible wave',
#  'rf',
#  'rms',
#  'rms roughness',
#  'rr',
#  'rubber-to-glass transition temperature',
#  's',
#  'sclc mobility',
#  'scratch resistance',
#  'secondary relaxations',
#  'self-diffusion coefficient',
#  'series resistance',
#  'shape fixation',
#  'shape parameter',
#  'shape recovery',
#  'sheet resistance',
#  'shell tg',
#  'short circuit current density',
#  'short-circuit current',
#  'short-circuit current density',
#  'short-circuit current density (j_{sc})',
#  'shoulder absorption range',
#  'shunt resistance',
#  'size',
#  'slope',
#  'specific capacitance',
#  'specific capacity',
#  'specific surface area',
#  'spin-coating speed',
#  'spin-coating time',
#  'stability',
#  'static contact angle',
#  'static dielectric constant',
#  'static tg',
#  'stiffness',
#  'stokes shift',
#  'storage modulus',
#  'stretching strength at 300 %',
#  'stretching strength at 300%',
#  'surface coverage',
#  'surface glass transition reduction',
#  'surface resistance',
#  'switching temperature',
#  'switching time',
#  't',
#  't hri',
#  't-5%',
#  't-50%',
#  't0',
#  't10',
#  't10%',
#  't5',
#  't5%',
#  't95%',
#  't_alpharelaxation',
#  't_beta',
#  't_break',
#  't_c',
#  't_d',
#  't_d 5%',
#  't_d-5-%',
#  't_d10',
#  't_d5',
#  't_d5%',
#  't_d50%',
#  't_g',
#  't_in',
#  't_{-5 %}',
#  't_{-50 %}',
#  't_{5 %}',
#  't_{50 %}',
#  't_{complete decomposition}',
#  't_{d5 %}',
#  't_{d5}',
#  't_{d}^{10}',
#  't_{m}',
#  'tan δ',
#  'tan δ peak temperature',
#  'tc',
#  'tcc',
#  'td',
#  'td (10% weight loss)',
#  'td (284-420)',
#  'td (5% weight loss)',
#  'td (50)',
#  'td (500)',
#  'td (air)',
#  'td (n2)',
#  'td (onset)',
#  'td value',
#  'td-10%',
#  'td-5-%',
#  'td-max',
#  'td10',
#  'td5',
#  'td5%',
#  'td50',
#  'td_10',
#  'td_5',
#  'td_max',
#  'td_{10}',
#  'td_{50}',
#  'td_{5}',
#  'td_{90}',
#  'te',
#  'temp',
#  'temperature at 10% mass loss',
#  'temperature at 10% weight loss',
#  'temperature at 5% weight loss',
#  'temperature at the maximum degradation rate',
#  'temperature of 5 wt % loss',
#  'temperature stability',
#  'tensile fracture stress',
#  'tensile modulus',
#  'tensile modulus improvement',
#  'tensile strain',
#  'tensile strength',
#  'tensile stress',
#  'tension',
#  'tg',
#  'tg (dsc)',
#  "tg (g'')",
#  'tg (hard block)',
#  'tg (main chain)',
#  'tg (side chain)',
#  'tg (soft block)',
#  'tg of amorphous polymer',
#  'tg range',
#  'tg transition',
#  'tg value',
#  'tg1',
#  'tg2',
#  'tg^ps',
#  'tga decomposition temperature',
#  'theoretical capacity',
#  'theoretical energy density',
#  'theoretical enthalpy of fusion',
#  'theoretical molecular weight of repeat unit',
#  'theoretical short-circuit current density',
#  'thermal conductivity',
#  'thermal decomposition loss',
#  'thermal decomposition temperature',
#  'thermal decomposition temperature (t_{-5 %})',
#  'thermal decomposition temperature (t_{-50 %})',
#  'thermal degradation',
#  'thermal degradation onset temperature',
#  'thermal degradation temperature',
#  'thermal properties',
#  'thermal stability',
#  'thermodynamic melting temperature',
#  'thickness',
#  'thr',
#  'ti',
#  'tin',
#  'tm',
#  'tmax',
#  'todt',
#  'todt of ordered lamellar morphology',
#  'torsion potential',
#  'torsion potential (ndi-btz)',
#  'total concentration',
#  'total negative charge',
#  'toughness',
#  'tp',
#  'transition temperature',
#  'transmittance',
#  'transmittance at 400 nm',
#  'ts',
#  'ttr',
#  'turn-on voltage',
#  'typical range of decomposition temperatures',
#  'tγ',
#  'ucst',
#  'ultimate elongation',
#  'ultimate strength',
#  'ultimate tensile strength',
#  'ultimate tensile stress',
#  'underwater chloroform ca',
#  'underwater oil contact angle',
#  'uoc',
#  'upper tg',
#  'utilization efficiency',
#  'uv-vis absorption peaks',
#  'uwoca of chloroform',
#  'v_oc',
#  'v_oc recovery',
#  'v_oc reduction',
#  'v_{oc}',
#  'viscosity',
#  'voc',
#  'voc expected',
#  'voltage',
#  'voltage where j_{ph} is zero',
#  'volume',
#  'volume fraction of gel polymers',
#  'volume fraction of water',
#  'volumetric capacitance',
#  'vptt',
#  'water absorption',
#  'water contact angle',
#  'water diffusivity',
#  'water regain',
#  'water swelling ratio',
#  'water uptake',
#  'wca in air',
#  'weight loss',
#  'weight loss at 300 °c',
#  'weight loss at 600 °c',
#  'weight loss at 800 °c',
#  'weight loss temperature',
#  'weight-loss onset temperature',
#  'weight-loss temperature of 5%',
#  'wetting by oil',
#  'width of unit',
#  'work function',
#  'xrd reflection',
#  'yc',
#  'yi',
#  'yield',
#  'yield strength',
#  "young's moduli",
#  "young's modulus",
#  'zeta potential',
#  'α',
#  'δcp',
#  'δhc',
#  'δhm',
#  'δod',
#  'δtg',
#  'δλ',
#  'ε',
#  'ε (1 mhz)',
#  "ε'",
#  "ε' at 1000 hz",
#  'εr',
#  "εr'",
#  'εγ',
#  'η',
#  'λ',
#  'λ value',
#  'λ_max red shift',
#  'λ_{max}',
#  'λmax',
#  'λmax (π-π* transition)',
#  'μe',
#  'μe/μh',
#  'μh',
#  'ω']

# %%
# Known property names.
knownprops = []
for row in postgres.raw_sql("""
    Select * From property_metadata;
"""):
    knownprops += row.other_names

knownprops = sorted([k.lower() for k in knownprops])
knownprops = list(set(knownprops))

print("Known polymer property names:", len(knownprops))
knownprops
# Out:
# Known polymer property names: 396
# ['energy density',
#  't_{c}',
#  'bandgaps',
#  'compressive stress',
#  'calculated molecular weight',
#  'refractive indices',
#  'glassy transition temperature (t g)',
#  'band gap energies',
#  'h2/co2 selectivity',
#  'specific capacity',
#  'highest occupied molecular orbital levels',
#  'light power conversion efficiency',
#  'relative crystallinity',
#  'm_{w}/m_{n}',
#  'current efficiency',
#  't_{g})',
#  'bending strength',
#  'm_{n}',
#  'polydispersity indices',
#  '% crystallinity',
#  'optical-band-gap energies',
#  'rejections',
#  'glass transition',
#  'lcst',
#  'power conversion efficiencies pces',
#  'water contact angle',
#  'glass transition temperature (tg)',
#  't g',
#  'compressive strengths',
#  'ocv',
#  'short-circuit density',
#  'areal power density',
#  'mn',
#  'bend strength',
#  't_d',
#  'j_{sc}',
#  'optical band gap energy',
#  'refractive index',
#  'tc',
#  "young's modulus",
#  'homo energy level',
#  'degrees of crystallinity (xc)',
#  'band-gaps',
#  'optical bandgaps',
#  'swelling degree',
#  'co2 permeance',
#  'minimum water adsorption',
#  'band gaps',
#  'bet surface areas',
#  'short-circuit current-density',
#  'viscosity',
#  'highest occupied molecular orbital level',
#  'lower critical solution temperatures',
#  'intrinsic viscosities',
#  'ion exchange capacity',
#  'highest-occupied molecular orbital levels',
#  'solar power conversion efficiency',
#  'coulombic efficiency',
#  'activation barrier',
#  'power-conversion efficiency',
#  'electrical band gap energy',
#  'optical energy gap',
#  'electrochemical band gaps',
#  'pce(η)',
#  'thermomechanical glass transition temperature (tg)',
#  'densities',
#  'optical band-gap',
#  'wca',
#  'holes mobility',
#  'pce_{max}',
#  'tensile strengths',
#  'electrical conductivity',
#  'sensitivity',
#  'tensile moduli',
#  'highest occupied molecular orbital energy levels',
#  'hole mobilities',
#  'tensile modulus',
#  'young modulus',
#  'capacitance retention',
#  'eqe_{max}',
#  'elec_bandgap',
#  'open-circuit voltages',
#  'melting points',
#  'upper critical solution temperatures',
#  'specific discharge capacity',
#  'youngs modulus',
#  'field-effect hole mobilities',
#  'glass transition temperature (crystal)',
#  'power factors',
#  'luminance',
#  'reversible capacity',
#  'discharge capacity',
#  'sheet resistances',
#  'areal current density',
#  'pure water flux',
#  'n-type mobility',
#  'lcsts',
#  'gravimetric energy density',
#  'swelling ratio',
#  'separation factors',
#  'water permeability',
#  'power conversion efficiency ηe',
#  'bulk glass transition temperature',
#  'specific capacitance',
#  'h_{2} permeability',
#  'homo level',
#  'eqe',
#  'crystallinity',
#  'light transmittance',
#  'co_{2}/n_{2} selectivity',
#  'lowest unoccupied molecular orbital energy',
#  "'zeta-potential, zetapotentials,zetapotential",
#  'maximum compressive strength',
#  'power density',
#  'thermal stability',
#  'thermal degradation',
#  'elongations at break',
#  'short circuit current density',
#  'swelling ratios',
#  'air permeability',
#  'band-gap',
#  'pdis',
#  'out-of-plane thermal conductivity',
#  'impact strength',
#  'oh^{-} conductivity',
#  'optical transmittance',
#  '% rejection',
#  'electrical resistivity',
#  'short-circuit current density',
#  'optical band gaps',
#  'relative permittivity',
#  "young 's modulus",
#  'fill-factor',
#  'modulus of rupture',
#  'homo levels',
#  'glass-transition temperatures',
#  'η',
#  'e_{g}',
#  'hole mobility',
#  'bandgap energy',
#  'bet surface area',
#  't_c',
#  'density',
#  'energy band gap',
#  'ion conductivity',
#  'fill factors',
#  'glass-transition temperature (t g)',
#  'maximal water uptake',
#  'ultimate strength',
#  'homo',
#  'highest occupied molecular orbit energy level',
#  'open circuit voltage',
#  'ionic conductivity',
#  'glass-transition temperature (bulk t_{g})',
#  'loi',
#  'm_w',
#  'optical bandgap',
#  'upper critical solution temperature',
#  'power factor',
#  'flexural strength',
#  'p-type mobilities',
#  'thermal decomposition temperature',
#  'compressive strength',
#  "young 's moduli",
#  'tensile strength',
#  'compressive moduli',
#  'activation enthalpy',
#  'i_{sc}',
#  'surface resistivity',
#  'degree of crystallinity',
#  'homo energy levels',
#  'lowest unoccupied energy level',
#  'external quantum efficiencies',
#  'conductivity',
#  'water flux',
#  'dielectric constants',
#  'open-circuit photovoltage',
#  'lumo levels',
#  'bandgap energies',
#  'reported glass transition temperature',
#  'ucsts',
#  'zetapotential',
#  "v_{oc}'s'",
#  "t_{g} 's",
#  'o2 permeability',
#  'zeta potential',
#  'intrinsic viscosity',
#  'power conversion efficiency η',
#  "young's moduli",
#  'energy bandgap',
#  'decomposition temperaturedegradation temperature',
#  'electron mobilities',
#  'co2/ch4 selectivity',
#  'resistivity',
#  'sensitivities',
#  'm',
#  'photovoltaic power conversion efficiency',
#  'am1 power conversion efficiency',
#  'adsorption capacities',
#  'pces',
#  'crystallinity levels',
#  'e_lumo',
#  'water contact angles',
#  'adsorption capacity',
#  'glass transition temperatures',
#  'dielectric breakdown strength',
#  'tg',
#  't m',
#  'oxygen permeability',
#  'e_{homo}',
#  'nacl rejection',
#  'shape recovery',
#  'contact angle',
#  'electrical conductivities',
#  'lumo energy',
#  'highest occupied molecular orbital energy level',
#  'inherent viscosity',
#  'salt rejection',
#  'optical energy bandgaps',
#  'highest occupied molecular orbital energy',
#  'thermal conductivities',
#  'glass-transition temperature (t_{g})',
#  'detection limit',
#  'crystallization temperature',
#  'fill factor ff',
#  'luminance efficiency',
#  'decomposition temperatures',
#  'thermal degradation temperature',
#  't_{d}',
#  'm_{w}m_{n}',
#  'm_{w}',
#  'water uptake',
#  'voc',
#  'fill factor',
#  'molecular weight',
#  'porosity',
#  'hydroxide conductivity',
#  'recovery',
#  'short-current density',
#  'activation energies',
#  'lumo value',
#  'lumo energy level',
#  'inherent viscosities',
#  'open circuit potential',
#  'brightness',
#  'activation energy',
#  'water-absorption',
#  'eqes',
#  'o2/n2 selectivity',
#  'homo energy',
#  'lumos',
#  'maximal water adsorption',
#  'rejection',
#  'v_{oc}',
#  'external quantum efficiency',
#  'detection limits',
#  'apparent viscosity',
#  'bandgap',
#  'open circuit voltages',
#  't_{g}s',
#  'h_{2}/co_{2} selectivity',
#  'hardness',
#  'glass transition temperature',
#  'average activation energies',
#  'dielectric loss',
#  'co2 permeability',
#  'tensile strength at break',
#  'current density',
#  'thermal conductivity',
#  'in-plane thermal conductivity',
#  'electron-mobilities',
#  'lumo energy levels',
#  'td',
#  'co_{2} permeance',
#  'number-average molecular weight',
#  'transverse rupture strength',
#  'v oc',
#  'short-circuit currents',
#  'co_{2}/ch_{4} selectivity',
#  'methanol permeability',
#  'homos',
#  't_{g}',
#  'melting temperatures',
#  'lowest unoccupied molecular orbital energy levels',
#  'fill-factors',
#  'gravimetric power density',
#  'white-light power conversion efficiency',
#  'water adsorption amount',
#  'melting point',
#  'iec',
#  'reported tg values',
#  'optical band gap',
#  'co_{2}n_{2} selectivity',
#  'ff',
#  'bandgap value',
#  'limiting oxygen index',
#  'lowest unoccupied molecular orbital level',
#  'capacitance retention rate',
#  'subglass transition temperature',
#  'short circuit current',
#  'ucst',
#  'h2 permeability',
#  'transmittances',
#  'elongation at break',
#  'o_{2}/n_{2} selectivity',
#  'breakdown field strength',
#  'power conversion efficiency',
#  'specific surface area',
#  'short-circuit current',
#  'number average molecular weight',
#  't_{m}',
#  'crystallinity degree',
#  'electron mobility',
#  'ion exchange capacities',
#  'power conversion efficiencies',
#  'pce',
#  'electrochemical band gap',
#  'light power conversion efficiencies',
#  'e_{lumo}',
#  'band gap',
#  'filling factor ff',
#  'brunauer-emmett-teller surface area',
#  'elongation-at-break',
#  'highest occupied molecular orbital',
#  'lumo',
#  'j sc',
#  'tensile stress',
#  't d',
#  'electric conductivity',
#  'separation factor',
#  'storage modulus',
#  'mw',
#  'molecular weights',
#  'thermal decomposition temperatures',
#  'short current density',
#  'compressive modulus',
#  'discharge capacities',
#  'white light power conversion efficiency',
#  'iecs',
#  'first glass transition temperature',
#  'o_{2} permeability',
#  'mean activation energies',
#  'crystallinity index',
#  'n-type mobilities',
#  'reflection loss',
#  'water adsorption',
#  'specific surface areas',
#  'proton conductivity',
#  'bandgap values',
#  'water fluxes',
#  'jsc',
#  'open-circuit voltage',
#  'saturation magnetization',
#  'co_{2} permeability',
#  'flexural strengths',
#  'surface area',
#  'band gap energy',
#  'lowest unoccupied molecular orbital',
#  'hole-mobilities',
#  'average coulombic efficiency',
#  'degradation temperatures',
#  'glass transitions',
#  'p-type mobility',
#  'short-circuit current densities',
#  'capacitance',
#  'apparent activation energy',
#  'sheet resistance',
#  'glass-transition temperature',
#  'water absorption',
#  'hydroxide ion conductivity',
#  'short-circuit photocurrent',
#  'water permeance',
#  'ffs',
#  'breakdown strength',
#  'lowest unoccupied molecular orbital energy level',
#  'lower critical solution temperature',
#  'viscosities',
#  'dielectric constant',
#  'transmittance',
#  't c',
#  'lumo level',
#  'glass transition temperature (t_{g})',
#  'v_{oc}s',
#  'hydrogen permeability',
#  'optical band-gaps',
#  'tm',
#  'melting temperature',
#  'lumo energies',
#  'ff s',
#  'surface glass transition temperature (tg)',
#  'calorimetric crystallinity',
#  'co2/n2 selectivity',
#  'na_{2}so_{4} rejection',
#  'polydispersity index',
#  'storage moduli',
#  'pdi']

# %%
# General extracted names.
method = postgres.raw_sql("""
    Select * From extraction_methods Where name = 'g-ner-gpt35-similar-sel1k';
""")[0]

gprops = postgres.raw_sql("""
SELECT DISTINCT(ep.entity_name) FROM extracted_properties ep
WHERE ep.method_id = :mid;""", mid = method.id)
gprops = [p.entity_name.lower() for p in gprops]
gprops = sorted(gprops)

print("Properties extracted by the general pipeline:", len(gprops))
gprops
# Out:
# Properties extracted by the general pipeline: 5341
# ['%',
#  '% crystallinity',
#  '% rejection',
#  '% xylose rejection',
#  '% χ c',
#  '%-elongation at break',
#  '%coverage',
#  '%de_{30}',
#  '%de_{90}',
#  '%i\\mu',
#  '(010) diffraction peak',
#  '(010) i-i stacking peak position',
#  '(010) scattering peak',
#  '(100) diffraction peaks',
#  '(100) scattering peak',
#  '(300) scattering peak',
#  '(dn/dc)μ',
#  '(oi)m',
#  '(δ m/ δ e)',
#  '(δ q/ δ e)',
#  '(τ_{ac} + τ_{br})',
#  '-(ch_{2}) n-protons of dodecyloxy group',
#  '-ch resonance',
#  '-och_{2} -groups attached to thiophene ring',
#  '-och_{2} ch_{2} peak',
#  '-so_{3} h absorption intensity',
#  '-δ s_{m}',
#  '0-0 absorption peak',
#  '0-0 transition',
#  '0-0 transition in film',
#  '0-0 transition in solution',
#  '0-1 absorption peak',
#  '0-1 transition',
#  '0-2 absorption peak',
#  '0-2 transition',
#  '1 % mass loss temperature',
#  '1 % weight loss temperature',
#  '1% weight loss temperature',
#  '1,4-cyclohexanedimethanol terephthalate content',
#  '1-0 transition',
#  '1/ c_{1}',
#  '1/n',
#  '10 % weight loss temperature',
#  '10 wt % weight loss temperature',
#  '10% decomposition temperature',
#  '10% degradation temperature',
#  '10% weight-loss temperature',
#  '13c nmr',
#  '1^{31} p-nmr',
#  '1h nmr spectra',
#  '1h nmr spectrum',
#  '1hnmr',
#  '2,6-dfbn (mmol)',
#  '2-0 transition',
#  '20% weight loss decomposition temperature',
#  '250 nm',
#  '2d flory exponent (v)',
#  '2θ',
#  '2θ angle',
#  '2θ d value',
#  '2θ scan data range',
#  '2θ value',
#  '2θ values',
#  "3-hydroxy-5-(4'-tolyl)valerate content",
#  '3-hydroxy-5-phenylvalerate content',
#  '3-hydroxyvalerate content',
#  '3ho content',
#  '4-mst moiety fraction',
#  '5 % weight loss temperature',
#  '5 % weight-loss temperature',
#  '5 wt % decomposition temperature (td5 %)',
#  '5 wt % loss temperature',
#  '5 wt % weight loss temperature',
#  '5% decomposition temperature',
#  '5% weight loss temperature',
#  '5% weight loss temperature (td5)',
#  '5% weight-loss temperature',
#  '50 % weight loss temperature',
#  '50 % weight-loss temperature',
#  '50% weight loss decomposition temperature',
#  '632 nm',
#  '< m_{n} >',
#  '< r^{2} > / m',
#  '<m_{n}>',
#  '<vh>',
#  '[1,4-dioxene]',
#  '[ibve-hcl]_3',
#  '[ibve-hcl]_{0}_{3}',
#  '[li]/[o]',
#  '[licl]/[bi] molar ratio',
#  '[licl]/[pbi] weight ratio',
#  '[m]/[i]',
#  '[m]/[i] ratio',
#  '[m]/[i] value',
#  '[mw/mn]',
#  '[pt-c]/[pbi] weight ratio',
#  '[η]^{a} (dl/g)',
#  '\\alpha',
#  '\\mu_{e}',
#  '^{13} c nmr',
#  '^{1} h nmr absorptions',
#  '^{1}^{13} c nmr signal',
#  '^{1}h nmr',
#  '^{1}h-nmr',
#  '^{31}p-nmr',
#  'a',
#  'a / a_{o} values',
#  'a b c',
#  'a_max',
#  'a_min',
#  'a_{m}',
#  'aa content',
#  'aa contents',
#  "abbe's number",
#  'abrasive size',
#  'absolute bioavailabilities',
#  'absolute bioavailability',
#  'absolute m_n',
#  'absolute molecular weight',
#  'absorbance',
#  'absorbance maximum (film)',
#  'absorbance peak',
#  'absorbance_band_1',
#  'absorbance_band_2',
#  'absorbed dose',
#  'absorbed doses',
#  'absorbed water content',
#  'absorbing n -aryl phenoxazine pcs',
#  'absorption',
#  'absorption band',
#  'absorption band 1',
#  'absorption band 2',
#  'absorption band edges',
#  'absorption band-edge',
#  'absorption bands',
#  'absorption bands (film)',
#  'absorption capacity',
#  'absorption characteristics',
#  'absorption coefficient',
#  'absorption coefficient at 550 nm',
#  'absorption coefficients',
#  'absorption edge',
#  'absorption edge (films)',
#  'absorption edge in solution',
#  'absorption edge in thin film',
#  'absorption edge of film',
#  'absorption edge optical band gap',
#  'absorption increase',
#  'absorption maxima',
#  'absorption maxima (film state)',
#  'absorption maxima (film)',
#  'absorption maxima (nmp solution)',
#  'absorption maxima (solid-state film)',
#  'absorption maxima (solution state)',
#  'absorption maxima (solution)',
#  'absorption maxima (λ_{max})',
#  'absorption maxima as a film',
#  'absorption maxima in chloroform solution',
#  'absorption maxima in film',
#  'absorption maxima in film state',
#  'absorption maxima in solid state',
#  'absorption maxima in solution',
#  'absorption maxima in thin films',
#  'absorption maximum',
#  'absorption maximum (chloroform)',
#  'absorption maximum (film)',
#  'absorption maximum (ict band)',
#  'absorption maximum (π-π* transition band)',
#  'absorption maximum blue shift',
#  'absorption maximum in film',
#  'absorption maximum in solution',
#  'absorption maximum in thin film',
#  'absorption maximum peak',
#  'absorption onset',
#  'absorption onset value',
#  'absorption onset wavelength',
#  'absorption onsets',
#  'absorption peak',
#  'absorption peak (dilute cb solution)',
#  'absorption peak (film)',
#  'absorption peak (long wavelength)',
#  'absorption peak (odcb solution)',
#  'absorption peak (short wavelength)',
#  'absorption peak (solution)',
#  'absorption peak (thin film)',
#  'absorption peak 1',
#  'absorption peak 2',
#  'absorption peak in film state',
#  'absorption peak in solution',
#  'absorption peak maxima in films',
#  'absorption peak maxima in solution',
#  'absorption peak wavelength',
#  'absorption peaks',
#  'absorption peaks (film)',
#  'absorption peaks (solid state)',
#  'absorption peaks (solution)',
#  'absorption peaks in chcl3 solution',
#  'absorption peaks in film state',
#  'absorption peaks in solid state',
#  'absorption peaks in solution',
#  'absorption peaks in thin film',
#  'absorption peaks in thin films',
#  'absorption range',
#  'absorption redshift',
#  'absorption shoulder',
#  'absorption spectra',
#  'absorption spectra broadening',
#  'absorption spectrum',
#  'absorption wavelength',
#  'absorption_band_1',
#  'absorption_band_2',
#  'absorption_edge',
#  'absorption_max',
#  'absorption_maxima',
#  'absorption_maxima_red_shift',
#  'absorption_peak_wavelength',
#  'absorptivity',
#  'acceleration voltage',
#  'acceptable stability profiles',
#  'accessibility efficacy of n active sites',
#  'accessible',
#  'accumulation of si on film surface',
#  'acetalization',
#  'acetalization level',
#  'acetone content',
#  'acetonitrile concentration',
#  'acetonitrile percentage',
#  'acid value',
#  'acidities',
#  'acidity threshold',
#  'acrylic acid content',
#  'acs (020)',
#  'acs (1 1 -0)',
#  'acs (110)',
#  'activation barrier',
#  'activation energies',
#  'activation energy',
#  'activation energy of curing reaction',
#  'activation energy of thermal decomposition',
#  'activation enthalpy',
#  'activation volume',
#  'active area',
#  'active energy of decomposition (stage 1)',
#  'active energy of decomposition (stage 2)',
#  'active film thickness',
#  'active layer thickness',
#  'active thickness',
#  'activity',
#  'ad',
#  'addition amount',
#  'additional absorption band',
#  'additional melting endotherm',
#  'additional relaxation',
#  'additional unique relaxations',
#  'additive concentration',
#  'additivity law',
#  'adhesion',
#  'adhesion pressure',
#  'adhesion strength',
#  'adhesive strength',
#  'adhesive strengths',
#  'adjusted to',
#  'adsorbed amount',
#  'adsorbed layer thickness',
#  'adsorption capacity',
#  'adsorption capacity for atz',
#  'adsorption capacity for cd (ii)',
#  'adsorption capacity for dur',
#  'adsorption capacity for pb (ii)',
#  'adsorptions',
#  'advancing water contact angle',
#  'after essay d',
#  'after essay mass',
#  'ag2---ag2* distance',
#  'agglomeration temperature',
#  'aggregation peak enthalpy',
#  'aggregation peak temperature',
#  'aggregation transition temperature',
#  'aging time',
#  'ag⋯ag distance',
#  'alkali resistance stability',
#  'alkoxy and n-alkyl side chain proton signals',
#  'alkylation yield',
#  'alkylphenoxy/phenoxy molar ratio',
#  'alpha',
#  'alpha r',
#  "alpha' transition temperature",
#  'alpha-cellulose',
#  'alpha-methyl peaks',
#  'alpha-methyl proton peaks',
#  'alpha-transition temperature',
#  'alpha_s/epsilon',
#  'am1.5g power conversion efficiency (pce)',
#  'amide bond absorption',
#  'amine content',
#  'amine equivalent weight',
#  'amino content',
#  'amino value',
#  'amorphous characteristics',
#  'amorphous content',
#  'amorphous phase',
#  'amorphous state',
#  'amount',
#  'amount obtained',
#  'amount of agalo2 nps',
#  'amount of dead chains',
#  'amount of extractables',
#  'amount of fluorocarbon',
#  'amount of plasticizer',
#  'amount used in dsc measurements',
#  'amounts',
#  'amylose content',
#  'an concentration',
#  'an loads',
#  'anaerobic char yield',
#  'anatase content (ac)',
#  'angle',
#  'aniline concentration',
#  'anisotropic molecular polarizabilities',
#  'anisotropic molecular polarizability',
#  'anneal temperature',
#  'annealed',
#  'annealing',
#  'annealing temperature',
#  'annealing time',
#  'annual increase rate',
#  'anodic current',
#  'anodic current of cc',
#  'anodic current of hq',
#  'anodic oxidation peak (first scan)',
#  'anodic oxidation peak (subsequent scans)',
#  'anodic oxidation peak current',
#  'anodic peak current-density',
#  'anodic peak potential',
#  'anodic wave',
#  'anti-hiv',
#  'antibacterial activity',
#  'anticancer activity',
#  'antifungal activities against c. glabrata',
#  'antimicrobial',
#  'antisymmetric c c stretching',
#  'antitumor',
#  'apparent activation energy',
#  'apparent density',
#  'apparent ea',
#  'apparent tg',
#  'apparent viscosity',
#  'appearance of ar-i',
#  'applied potential',
#  'applied potentials',
#  'approximate',
#  'aqueous solubility',
#  'area',
#  'area mass loading',
#  'area per chain',
#  'area per molecule',
#  'area under the stress-strain curve',
#  'areal capacitance',
#  'aromatic',
#  'aromatic content',
#  'aromatic hydrogen resonance',
#  'aromatic resonance',
#  'ash content',
#  'aspect ratio',
#  'asymmetric stretching vibrations',
#  'at 600 °c',
#  'at amount',
#  'au accumulation in tumors',
#  'au concentration',
#  'auc_{0-2} h μg min/ml',
#  'average',
#  'average activation energies',
#  'average apparent thermal decomposition activation energies',
#  'average area per po monomeric unit',
#  'average coulombic efficiency',
#  'average degree of polymerization (dp)',
#  'average diameter',
#  'average diameter of microspheres',
#  'average diffusion coefficient',
#  'average electron mobility',
#  'average fet hole mobilities',
#  'average fiber diameter',
#  'average flux',
#  'average heating rate',
#  'average hole mobilities',
#  'average hole mobility',
#  'average hole volume',
#  'average hopping distance',
#  'average inter-ring angle',
#  'average inter-ring torsional angle',
#  'average length',
#  'average m_{n}',
#  'average mn',
#  'average mobilities',
#  'average mobility',
#  'average molar areas at full coverage',
#  'average molar areas at low coverage',
#  'average molar mass',
#  'average molecular mass',
#  'average molecular occupied surface area',
#  'average molecular weight',
#  'average molecular weight (_{w})',
#  'average molecular weight between crosslinks',
#  'average molecular weight of chain',
#  'average mw',
#  'average mw',
#  'average mw',
#  'average number molecular weight',
#  'average orientation of donor-and acceptor-dipoles',
#  'average particle size',
#  'average particles',
#  'average pce',
#  'average pore area',
#  'average pore size',
#  'average porosity',
#  'average potential for formation of doped state',
#  'average power conversion efficiency',
#  'average size',
#  'average tg',
#  'average weight average molecular weight (m_{w})',
#  'average weight molar mass',
#  'average width',
#  'average-number molecular weight',
#  'averaged for analyses',
#  'avogadro number',
#  'avrami exponent',
#  'avrami exponent value',
#  'avrami index',
#  'avt',
#  'avts',
#  'axial resolution',
#  'azeotropic point',
#  'b',
#  'b',
#  'b value',
#  'ba content',
#  'back pressure',
#  'backbone bond length',
#  'bacterial count number',
#  'bake temperature',
#  'baking',
#  'baking temperature',
#  'balance',
#  'ball milling speed',
#  'ballistic cooling rate',
#  'band',
#  'band edge',
#  'band gap',
#  'band gap energies',
#  'band gap energy',
#  'band gap in film',
#  'band gap in thin film',
#  'band gaps',
#  'band-gap',
#  'band-gaps',
#  'bandgap',
#  'bandgap energy',
#  'bandgap interval',
#  'bandgap value',
#  'bandgap values',
#  'bands',
#  'barrier between the two minima at α ~ 90°',
#  'barrier height',
#  'barrier to planarity at α ~ 135°',
#  'barrier to planarity at α ~ 30°',
#  'base pressure',
#  'based on',
#  'baseline concentration',
#  'bathochromic shift',
#  'bathochromic_shift',
#  'battery cracking',
#  'battery cycling',
#  'beads',
#  'bearing strength',
#  'benchmark values',
#  'bending strength',
#  'benzene release',
#  'bet surface area',
#  'beta relaxation maxima',
#  'beta relaxation temperature',
#  'beta-transition temperature',
#  'between major and minor peaks',
#  'bias stress testing time',
#  'bias voltage',
#  'bif',
#  'bifp',
#  'binding energies',
#  'binding energy',
#  'bio-content',
#  'bioavailabilities',
#  'biodegraded',
#  'biomass',
#  'birefringence',
#  'bla',
#  'blend',
#  'blend component',
#  'blend composition',
#  'blend layer thickness',
#  'blend ratio',
#  'blend ratios',
#  'blended host',
#  'blended solution',
#  'blended with mdmo-ppv',
#  'blending temperature',
#  'block copolymerization',
#  'block size',
#  'blue emission peak shift',
#  'blue shift',
#  'blue-shift',
#  'boiling point',
#  'boiling-point',
#  'bond angle',
#  'bond angles',
#  'bond energy',
#  'bond length',
#  'bond lengths',
#  'bonding pressure',
#  'bonding temperature',
#  'box size',
#  'bp',
#  'bpa concentration',
#  'branching density',
#  'branching structures',
#  'break point frequency',
#  'breakdown',
#  'breakdown events range',
#  'breakdown strength',
#  'breaking strain',
#  'breaking stress',
#  'breaking tensile strain',
#  'breaking tensile stress',
#  'brightness',
#  'brightness enhancement',
#  'brightness enhancement factor',
#  'brightness levels',
#  'broad feature',
#  'broadening of glass transition peaks',
#  'broken',
#  'bromination yield',
#  'built-in voltage',
#  'bulk concentration',
#  'bulk density',
#  'bulk enthalpy of crystallization',
#  'bulk glass transition temperature',
#  'bulk modulus',
#  'bulk swellability',
#  'bulk t_{g}',
#  'bulk tg',
#  'burning extent',
#  'butadiene content',
#  'byproduct',
#  'c',
#  'c 1s xps peak',
#  'c : p elemental ratio',
#  'c atomic percentage',
#  'c c bond peak',
#  'c c stretching bands',
#  'c content',
#  'c h bending',
#  'c h out-of-plane vibrations',
#  'c ips? o ips? c ether group absorption',
#  'c nmr',
#  'c nmr signal',
#  'c o bond peak',
#  'c o stretching vibration',
#  'c o stretching vibrations',
#  'c range',
#  'c t_{∞}',
#  "c'_h",
#  'c-c bond length',
#  'c-c bond length (double bond)',
#  'c-c bond length (single bond)',
#  'c-c separation',
#  'c-c single bond distance',
#  'c-h stretching aliphatic segments',
#  'c-h stretching vibrations',
#  'c-n bond stretching vibration',
#  'c-o bond length',
#  'c-o separation',
#  'c-o-c stretching of ether bond',
#  'c/n ratio',
#  'c/o atomic ratio',
#  'c1',
#  'c2',
#  'c=c bond length',
#  'c=o bond stretching vibration',
#  'c=o stretching',
#  'c=o stretching band (acetyl group)',
#  'c=o stretching band (carboxyl groups)',
#  'c_d+1',
#  'c_pabis',
#  'c_{3} h_{6} permeability',
#  'c_{3} h_{8} permeability',
#  'c_{e}',
#  'ca accumulation in tumors',
#  'ca concentration',
#  'ca/p molar ratio',
#  'calcd. p %',
#  'calcination temperature',
#  'calculated',
#  'calculated carbon weight percentage',
#  'calculated d-spacing',
#  'calculated hydrogen weight percentage',
#  'calculated mass',
#  'calculated molecular weight',
#  'calculated nitrogen weight percentage',
#  'calculated value',
#  'calculated value of char residue at 700 ° c',
#  'calorimetric crystallinity',
#  'calorimetric melting temperature',
#  'capacitance',
#  'capacitance per unit area',
#  'capacitance retention',
#  'capacitances of the coatings',
#  'capacity',
#  'capacity loss',
#  'capacity retention',
#  'carbazole ring protons (4, 5-positions) peak',
#  'carbon consumption',
#  'carbon weight percentage',
#  'carbon yield at 900 °c',
#  'carbonate content',
#  'carbonate group content',
#  'carbonate linkage',
#  'carbonate selectivity',
#  'carbonyl absorption band',
#  'carbonyl absorption band (crystalline)',
#  'carbonyl absorption band (noncrystalline)',
#  'carbonyl peaks',
#  'carrier density',
#  'carrier mobility',
#  'cas',
#  'catalysed',
#  'catalyst',
#  'catalyst activity',
#  'catalyst activity in ch_{2} cl_{2}',
#  'catalyst activity in toluene',
#  'catalyst amount',
#  'catalyst concentration',
#  'catalyst efficiency',
#  'catalyst l 1 zn',
#  'catalyst loading',
#  'catalyst system',
#  'catalysts',
#  'catalytic activity',
#  'catalytic activity in chloroform',
#  'catalytic activity in dichloromethane',
#  'catalytic activity in dioxolane',
#  'catalytic activity in toluene',
#  'catalytic efficiency',
#  'cathodic peak',
#  'cathodic peak potential',
#  'cathodic peak wavelength',
#  'cathodic potential',
#  'cc distance',
#  'cd2+ adsorption efficiency',
#  'cdm',
#  'ce',
#  'ce at 1080 nm',
#  'ce at 500 nm',
#  'ced',
#  'cell capacitance',
#  'cell densities',
#  'cell density',
#  'cell dimensions',
#  'cell distortion',
#  'cell killing',
#  'cell parameters',
#  'cell size',
#  'cell sizes',
#  'cell viability',
#  'cell viability',
#  'cell voltage',
#  'cellulose content',
#  'cellulose digestibility',
#  'centrifugation speed',
#  'ch2/co ratio',
#  'ch3 rocking vibrations',
#  'ch4 diffusion coefficient',
#  'ch4 solubility coefficient',
#  'chain end structures',
#  'chain length',
#  'chain transfer constant',
#  'change in diffraction peak position',
#  'change in enthalpy',
#  'change in i_{pa}',
#  'change in peak position',
#  'change in storage modulus',
#  'change in t_{g}',
#  'change in torsional profile as a function of oligomer length',
#  'change in ρ',
#  'changes in m_{x}',
#  'channel length',
#  'channel width',
#  'char at 1000 °c',
#  'char residue at 700 ° c',
#  'char yield',
#  'char yield at 600 °c',
#  'char yield at 700 °c',
#  'char yield at 800 °c',
#  'char yields',
#  'char yields at 800 °c',
#  'characteristic dielectric strength',
#  'characteristic length',
#  'characteristic molecular weight',
#  'characteristic ratio',
#  'characteristic ratio c_{∞}',
#  'characteristic timescale (faster process)',
#  'characteristic timescale (slower process)',
#  'characteristic wavelength',
#  'charcoal formation',
#  'charge',
#  'charge capacity',
#  'charge carrier mobility',
#  'charge density',
#  'charge for cooking',
#  'charge for monolayer adsorption of h_{2} on pt surfaces',
#  'charge mobility',
#  'charge per unit area after 500 cycles',
#  'charge per unit area at 1st cycle',
#  'charge ratio',
#  'charge recombination lifetime',
#  'charge separation',
#  'charge transfer energy',
#  'charge transfer peak',
#  'charge transfer resistance',
#  'charge transport',
#  'chcl3-insoluble part',
#  'chemical compositions',
#  'chemical formula',
#  'chemical reactions temperature 1',
#  'chemical reactions temperature 2',
#  'chemical shift',
#  'chemical shift range',
#  'chemical shift reference',
#  'chemical shifts',
#  'chemical stability',
#  'chiral centers',
#  'chlorine content',
#  'chromophore concentration',
#  'chromophore concentrations',
#  'cie 1931 coordinates',
#  'cie coordinates',
#  'cie coordinates change',
#  'cie values',
#  'cips 3/4o stretching band',
#  'cis',
#  'cis / trans in 1,4 structure',
#  'cis content',
#  'cl',
#  'cl content',
#  'clay content',
#  'cleaning solution',
#  'cleaning temperature',
#  'clearing temperature',
#  'closest o⋯o distance',
#  'cloud point',
#  'cm^{-1}',
#  'cmc',
#  'cmc',
#  'cn group absorption',
#  'cn stretching band',
#  'cnc content',
#  'co bond length',
#  'co distance',
#  'co-network',
#  'co-solvent composition',
#  'co2',
#  'co2 permeability',
#  'co2/ch4 selectivity',
#  'co2/h2 selectivity',
#  'co2/n2 diffusion selectivity',
#  'co2/n2 selectivity',
#  'co2/n2 solubility selectivity',
#  'co_{2} permeability',
#  'co_{2}/ch_{4} ideal selectivity',
#  'co_{2}/ch_{4} selectivity',
#  'coating',
#  'coating capacitance',
#  'coating efficiency',
#  'coating impedance',
#  'coating level',
#  'coating temperature',
#  'coefficient',
#  'coefficient of correlation (r^2)',
#  'coefficient of thermal expansion',
#  'coercive force',
#  'coercivity',
#  'coherence length',
#  'cohesive energy',
#  'cold crystallisation exotherm',
#  'cold crystallization',
#  'cold crystallization peak',
#  'cold crystallization point',
#  'cold crystallization temperature',
#  'color change',
#  'color contrast',
#  'color coordinates',
#  'color coordinates (yxy)',
#  'color difference',
#  'color purity',
#  'color rendering index',
#  'color saturation',
#  'coloration efficiency',
#  'coloration efficiency (ce)',
#  'coloration rate',
#  'column dimensions',
#  'column length',
#  'column size',
#  'column temperature',
#  'combination of sec and maldi-tof mass spectrometry',
#  'commission internationale d-eclairage coordinates',
#  "commission internationale de l'eclairage 1931 coordinates",
#  'comonomer composition',
#  'comonomer feeding ratios',
#  'compare favorably',
#  'competitive capacity',
#  'completely cured resin',
#  'complex rate constant',
#  'complex viscosity',
#  'complexing abilities',
#  'composition',
#  'compositions',
#  'compression',
#  'compression stress',
#  'compressive modulus',
#  'compressive strain',
#  'compressive strength',
#  'compressive stress',
#  'concentration',
#  'concentration factor',
#  'concentration in chlorobenzene',
#  'concentration of cnf',
#  'concentration of hq and cc',
#  'concentration of salt',
#  'concentration profile',
#  'concentration range',
#  'concentrations',
#  'conductance increase',
#  'conductivities',
#  'conductivity',
#  'conductivity (dedoped)',
#  'conductivity (doped with fecl3)',
#  'conductivity (doped with i2)',
#  'conductivity (doped with nobf4)',
#  'conductivity (fecl3 doping)',
#  'conductivity contrast',
#  'conductivity response',
#  'conductivity values',
#  'conjugated fraction',
#  'conjugated pfa tg',
#  'conjugated polymer photovoltaic materials with broad absorption band and high charge carrier mobility',
#  'conjugated structure',
#  'conjugation length',
#  'consecutive cycles',
#  'consistency coefficient',
#  'constant',
#  'constant value',
#  'consumed',
#  'contact angle',
#  'contact angle after grafting',
#  'contact angle at 25 °c',
#  'contact angle at 45 °c',
#  'contact angle at room temperature',
#  'contact angle before grafting',
#  'contact angle change',
#  'contact angle when heated',
#  'contact angle with water',
#  'contact resistance (rc1)',
#  'contact resistivity',
#  'contact resistivity (rc2)',
#  'contamination',
#  'content',
#  'content of 1,4-repeating unit',
#  'content of h-units',
#  'content of methyl ester monomer unit',
#  'content of unreacted vinyl groups',
#  'content ratio',
#  'contents of daa-gptms',
#  'contents of hbn-oh',
#  'contrast',
#  'contribution ratio',
#  'contribution to climate warming',
#  'conv',
#  'conventional polymers',
#  'conversion',
#  'conversion efficiency',
#  'conversion of nbma',
#  'conversions',
#  'cooking liquor to fibre ratio',
#  'cooled to',
#  'cooling phase transition',
#  'cooling rate',
#  'cooling rates',
#  'coordination',
#  'coordination number',
#  'copolymer concentration',
#  'copolymerization ratio',
#  'copper concentration',
#  'core size',
#  'core tg',
#  'core-shell-corona micelles size',
#  'core/shell micelles size',
#  'correlation coefficient',
#  'corresponding enthalpy value of cold crystallization',
#  'corrosion current density',
#  'corrosion potential',
#  'corrosion resistance',
#  'cos',
#  'cost',
#  'coulombic efficiencies',
#  'coulombic efficiency',
#  'counter-ion',
#  'cp',
#  'cp change',
#  'cr2+ adsorption efficiency',
#  'crack-onset strain',
#  'creep strain',
#  'cri value change',
#  'cri values',
#  'critical angle',
#  'critical conversion',
#  'critical exponent',
#  'critical forster distance',
#  'critical micelle concentration',
#  'critical micelle concentration (cmc)',
#  'critical molar fraction',
#  'critical molecular weight',
#  'critical mw',
#  'critical temperature',
#  'critical thickness',
#  'critical value',
#  'critical value χc',
#  'cross-head speed',
#  'cross-linking density',
#  'cross-linking efficiency',
#  'cross-sectional area',
#  'cross-sectional radius',
#  'crosslink density',
#  'crosslinked with 3% taic',
#  'crosslinking',
#  'crosslinking degrees',
#  'crosslinking temperature',
#  'crossover',
#  'crystal coherence length (ccl)',
#  'crystal lamellar thickness',
#  'crystal melting temperature',
#  'crystal size',
#  'crystal sizes',
#  'crystal structure',
#  'crystalline content',
#  'crystalline degree',
#  'crystalline melting point',
#  'crystalline peak',
#  'crystalline polymer melting enthalpy',
#  'crystallinity',
#  'crystallinity',
#  'crystallinity after 32 weeks of degradation',
#  'crystallinity and tm changes onset temperature',
#  'crystallinity before degradation',
#  'crystallinity degree',
#  'crystallinity index',
#  'crystallinity levels',
#  'crystallisation temperature',
#  'crystallite size',
#  'crystallization',
#  'crystallization exotherm temperature',
#  'crystallization exothermal peak',
#  'crystallization exothermic peak',
#  'crystallization exothermic peak temperature',
#  'crystallization kinetics',
#  'crystallization peak',
#  'crystallization peak temperature',
#  'crystallization temperature',
#  'crystallization transition',
#  'crystallization-rate maxima',
#  'cs+ counterions',
#  'csf concentration',
#  'ct band red shift',
#  'cta content',
#  'cta/initiator molar ratio',
#  'cte',
#  'cte value',
#  'cte values',
#  'cu***cu distance',
#  'cu2+ adsorption efficiency',
#  'culture volume',
#  'cuo peak',
#  'cure temperature',
#  'cure temperatures',
#  'cure-temperature',
#  'curing peak temperature',
#  'current',
#  'current at 200 k',
#  'current at 250 k',
#  'current bump',
#  'current carrying capacity',
#  'current change',
#  'current density',
#  'current efficiency',
#  ...]

# %%
# Extra properties.
extraprops = []
for prop in gprops:
    if prop not in propnames:
        extraprops.append(prop)

print("Properties extracted by the general pipeline, but not by the property specific pipeline:", len(extraprops))
extraprops
# Out:
# Properties extracted by the general pipeline, but not by the property specific pipeline: 4634
# ['%',
#  '% crystallinity',
#  '% rejection',
#  '% xylose rejection',
#  '% χ c',
#  '%de_{30}',
#  '%de_{90}',
#  '%i\\mu',
#  '(010) diffraction peak',
#  '(010) i-i stacking peak position',
#  '(010) scattering peak',
#  '(100) diffraction peaks',
#  '(100) scattering peak',
#  '(300) scattering peak',
#  '(dn/dc)μ',
#  '(oi)m',
#  '(δ m/ δ e)',
#  '(δ q/ δ e)',
#  '(τ_{ac} + τ_{br})',
#  '-(ch_{2}) n-protons of dodecyloxy group',
#  '-ch resonance',
#  '-och_{2} -groups attached to thiophene ring',
#  '-och_{2} ch_{2} peak',
#  '-so_{3} h absorption intensity',
#  '-δ s_{m}',
#  '0-0 absorption peak',
#  '0-0 transition',
#  '0-0 transition in film',
#  '0-0 transition in solution',
#  '0-1 absorption peak',
#  '0-2 absorption peak',
#  '1 % mass loss temperature',
#  '1 % weight loss temperature',
#  '1,4-cyclohexanedimethanol terephthalate content',
#  '1/ c_{1}',
#  '1/n',
#  '13c nmr',
#  '1^{31} p-nmr',
#  '1h nmr spectra',
#  '1h nmr spectrum',
#  '1hnmr',
#  '2,6-dfbn (mmol)',
#  '250 nm',
#  '2d flory exponent (v)',
#  '2θ',
#  '2θ angle',
#  '2θ d value',
#  '2θ scan data range',
#  '2θ value',
#  '2θ values',
#  "3-hydroxy-5-(4'-tolyl)valerate content",
#  '3-hydroxy-5-phenylvalerate content',
#  '3-hydroxyvalerate content',
#  '3ho content',
#  '4-mst moiety fraction',
#  '5 % weight loss temperature',
#  '5 % weight-loss temperature',
#  '5 wt % decomposition temperature (td5 %)',
#  '5 wt % loss temperature',
#  '5 wt % weight loss temperature',
#  '5% weight loss temperature (td5)',
#  '5% weight-loss temperature',
#  '50 % weight loss temperature',
#  '50 % weight-loss temperature',
#  '632 nm',
#  '< m_{n} >',
#  '< r^{2} > / m',
#  '<m_{n}>',
#  '<vh>',
#  '[1,4-dioxene]',
#  '[ibve-hcl]_3',
#  '[ibve-hcl]_{0}_{3}',
#  '[li]/[o]',
#  '[licl]/[bi] molar ratio',
#  '[licl]/[pbi] weight ratio',
#  '[m]/[i]',
#  '[m]/[i] ratio',
#  '[m]/[i] value',
#  '[mw/mn]',
#  '[pt-c]/[pbi] weight ratio',
#  '[η]^{a} (dl/g)',
#  '\\alpha',
#  '\\mu_{e}',
#  '^{13} c nmr',
#  '^{1} h nmr absorptions',
#  '^{1}^{13} c nmr signal',
#  '^{1}h nmr',
#  '^{1}h-nmr',
#  '^{31}p-nmr',
#  'a',
#  'a / a_{o} values',
#  'a b c',
#  'a_max',
#  'a_min',
#  'a_{m}',
#  'aa content',
#  'aa contents',
#  "abbe's number",
#  'abrasive size',
#  'absolute bioavailabilities',
#  'absolute bioavailability',
#  'absolute m_n',
#  'absolute molecular weight',
#  'absorbance',
#  'absorbance maximum (film)',
#  'absorbance peak',
#  'absorbance_band_1',
#  'absorbance_band_2',
#  'absorbed dose',
#  'absorbed doses',
#  'absorbed water content',
#  'absorbing n -aryl phenoxazine pcs',
#  'absorption',
#  'absorption band 1',
#  'absorption band 2',
#  'absorption band-edge',
#  'absorption bands (film)',
#  'absorption capacity',
#  'absorption characteristics',
#  'absorption coefficient at 550 nm',
#  'absorption coefficients',
#  'absorption edge (films)',
#  'absorption edge in solution',
#  'absorption edge in thin film',
#  'absorption edge of film',
#  'absorption increase',
#  'absorption maxima (film state)',
#  'absorption maxima (film)',
#  'absorption maxima (nmp solution)',
#  'absorption maxima (solid-state film)',
#  'absorption maxima (solution state)',
#  'absorption maxima (solution)',
#  'absorption maxima (λ_{max})',
#  'absorption maxima as a film',
#  'absorption maxima in chloroform solution',
#  'absorption maxima in film',
#  'absorption maxima in film state',
#  'absorption maxima in solid state',
#  'absorption maxima in solution',
#  'absorption maxima in thin films',
#  'absorption maximum (chloroform)',
#  'absorption maximum (film)',
#  'absorption maximum (ict band)',
#  'absorption maximum (π-π* transition band)',
#  'absorption maximum blue shift',
#  'absorption maximum in film',
#  'absorption maximum in thin film',
#  'absorption maximum peak',
#  'absorption onset wavelength',
#  'absorption onsets',
#  'absorption peak (dilute cb solution)',
#  'absorption peak (film)',
#  'absorption peak (long wavelength)',
#  'absorption peak (odcb solution)',
#  'absorption peak (short wavelength)',
#  'absorption peak (solution)',
#  'absorption peak (thin film)',
#  'absorption peak 1',
#  'absorption peak 2',
#  'absorption peak in film state',
#  'absorption peak in solution',
#  'absorption peak maxima in films',
#  'absorption peak maxima in solution',
#  'absorption peak wavelength',
#  'absorption peaks',
#  'absorption peaks (film)',
#  'absorption peaks (solid state)',
#  'absorption peaks (solution)',
#  'absorption peaks in chcl3 solution',
#  'absorption peaks in film state',
#  'absorption peaks in solid state',
#  'absorption peaks in thin film',
#  'absorption peaks in thin films',
#  'absorption redshift',
#  'absorption shoulder',
#  'absorption spectra broadening',
#  'absorption wavelength',
#  'absorption_band_1',
#  'absorption_band_2',
#  'absorption_edge',
#  'absorption_max',
#  'absorption_maxima',
#  'absorption_maxima_red_shift',
#  'absorption_peak_wavelength',
#  'absorptivity',
#  'acceleration voltage',
#  'acceptable stability profiles',
#  'accessibility efficacy of n active sites',
#  'accessible',
#  'accumulation of si on film surface',
#  'acetalization',
#  'acetalization level',
#  'acetone content',
#  'acetonitrile concentration',
#  'acetonitrile percentage',
#  'acidities',
#  'acidity threshold',
#  'acrylic acid content',
#  'acs (020)',
#  'acs (1 1 -0)',
#  'acs (110)',
#  'activation barrier',
#  'activation energies',
#  'activation energy of curing reaction',
#  'activation energy of thermal decomposition',
#  'activation enthalpy',
#  'activation volume',
#  'active energy of decomposition (stage 1)',
#  'active energy of decomposition (stage 2)',
#  'active film thickness',
#  'active thickness',
#  'activity',
#  'ad',
#  'addition amount',
#  'additional absorption band',
#  'additional melting endotherm',
#  'additional relaxation',
#  'additional unique relaxations',
#  'additive concentration',
#  'additivity law',
#  'adhesion',
#  'adhesion pressure',
#  'adhesion strength',
#  'adhesive strength',
#  'adhesive strengths',
#  'adjusted to',
#  'adsorbed amount',
#  'adsorption capacity',
#  'adsorption capacity for atz',
#  'adsorption capacity for cd (ii)',
#  'adsorption capacity for dur',
#  'adsorption capacity for pb (ii)',
#  'adsorptions',
#  'after essay d',
#  'after essay mass',
#  'ag2---ag2* distance',
#  'agglomeration temperature',
#  'aggregation peak enthalpy',
#  'aggregation peak temperature',
#  'aging time',
#  'ag⋯ag distance',
#  'alkali resistance stability',
#  'alkoxy and n-alkyl side chain proton signals',
#  'alkylation yield',
#  'alkylphenoxy/phenoxy molar ratio',
#  'alpha r',
#  "alpha' transition temperature",
#  'alpha-cellulose',
#  'alpha-methyl peaks',
#  'alpha-methyl proton peaks',
#  'alpha-transition temperature',
#  'alpha_s/epsilon',
#  'am1.5g power conversion efficiency (pce)',
#  'amide bond absorption',
#  'amine content',
#  'amine equivalent weight',
#  'amino content',
#  'amino value',
#  'amorphous characteristics',
#  'amorphous content',
#  'amorphous phase',
#  'amorphous state',
#  'amount obtained',
#  'amount of agalo2 nps',
#  'amount of dead chains',
#  'amount of extractables',
#  'amount of fluorocarbon',
#  'amount of plasticizer',
#  'amount used in dsc measurements',
#  'amounts',
#  'amylose content',
#  'an concentration',
#  'an loads',
#  'anaerobic char yield',
#  'anatase content (ac)',
#  'angle',
#  'aniline concentration',
#  'anisotropic molecular polarizabilities',
#  'anisotropic molecular polarizability',
#  'anneal temperature',
#  'annealed',
#  'annealing',
#  'annealing time',
#  'annual increase rate',
#  'anodic current',
#  'anodic current of cc',
#  'anodic current of hq',
#  'anodic oxidation peak (first scan)',
#  'anodic oxidation peak (subsequent scans)',
#  'anodic oxidation peak current',
#  'anodic peak potential',
#  'anodic wave',
#  'anti-hiv',
#  'antibacterial activity',
#  'anticancer activity',
#  'antifungal activities against c. glabrata',
#  'antimicrobial',
#  'antisymmetric c c stretching',
#  'antitumor',
#  'apparent activation energy',
#  'apparent ea',
#  'apparent tg',
#  'appearance of ar-i',
#  'applied potential',
#  'applied potentials',
#  'approximate',
#  'aqueous solubility',
#  'area',
#  'area mass loading',
#  'area per chain',
#  'area per molecule',
#  'area under the stress-strain curve',
#  'aromatic',
#  'aromatic content',
#  'aromatic hydrogen resonance',
#  'aromatic resonance',
#  'ash content',
#  'aspect ratio',
#  'asymmetric stretching vibrations',
#  'at 600 °c',
#  'at amount',
#  'au accumulation in tumors',
#  'au concentration',
#  'auc_{0-2} h μg min/ml',
#  'average',
#  'average activation energies',
#  'average apparent thermal decomposition activation energies',
#  'average area per po monomeric unit',
#  'average coulombic efficiency',
#  'average degree of polymerization (dp)',
#  'average diameter',
#  'average diameter of microspheres',
#  'average diffusion coefficient',
#  'average electron mobility',
#  'average fet hole mobilities',
#  'average fiber diameter',
#  'average flux',
#  'average heating rate',
#  'average hole mobilities',
#  'average hole mobility',
#  'average hopping distance',
#  'average inter-ring angle',
#  'average inter-ring torsional angle',
#  'average length',
#  'average m_{n}',
#  'average mn',
#  'average mobilities',
#  'average mobility',
#  'average molar areas at full coverage',
#  'average molar areas at low coverage',
#  'average molar mass',
#  'average molecular mass',
#  'average molecular occupied surface area',
#  'average molecular weight',
#  'average molecular weight (_{w})',
#  'average molecular weight between crosslinks',
#  'average mw',
#  'average mw',
#  'average mw',
#  'average number molecular weight',
#  'average orientation of donor-and acceptor-dipoles',
#  'average particle size',
#  'average particles',
#  'average pce',
#  'average pore area',
#  'average pore size',
#  'average porosity',
#  'average potential for formation of doped state',
#  'average power conversion efficiency',
#  'average tg',
#  'average weight average molecular weight (m_{w})',
#  'average weight molar mass',
#  'average width',
#  'average-number molecular weight',
#  'averaged for analyses',
#  'avogadro number',
#  'avrami exponent',
#  'avrami exponent value',
#  'avrami index',
#  'avt',
#  'avts',
#  'axial resolution',
#  'azeotropic point',
#  'b',
#  'b',
#  'b value',
#  'ba content',
#  'back pressure',
#  'backbone bond length',
#  'bacterial count number',
#  'bake temperature',
#  'baking',
#  'baking temperature',
#  'balance',
#  'ball milling speed',
#  'ballistic cooling rate',
#  'band',
#  'band edge',
#  'band gap energies',
#  'band gap in film',
#  'band gap in thin film',
#  'band gaps',
#  'band-gaps',
#  'bandgap interval',
#  'bandgap value',
#  'bands',
#  'barrier between the two minima at α ~ 90°',
#  'barrier to planarity at α ~ 135°',
#  'barrier to planarity at α ~ 30°',
#  'base pressure',
#  'based on',
#  'baseline concentration',
#  'bathochromic shift',
#  'bathochromic_shift',
#  'battery cracking',
#  'battery cycling',
#  'beads',
#  'bearing strength',
#  'benchmark values',
#  'benzene release',
#  'bet surface area',
#  'beta relaxation maxima',
#  'beta relaxation temperature',
#  'beta-transition temperature',
#  'between major and minor peaks',
#  'bias stress testing time',
#  'bias voltage',
#  'bif',
#  'bifp',
#  'binding energies',
#  'binding energy',
#  'bio-content',
#  'bioavailabilities',
#  'biodegraded',
#  'biomass',
#  'birefringence',
#  'bla',
#  'blend',
#  'blend component',
#  'blend composition',
#  'blend layer thickness',
#  'blend ratios',
#  'blended host',
#  'blended solution',
#  'blended with mdmo-ppv',
#  'blending temperature',
#  'block copolymerization',
#  'block size',
#  'blue emission peak shift',
#  'blue shift',
#  'blue-shift',
#  'boiling point',
#  'boiling-point',
#  'bond angle',
#  'bond angles',
#  'bond energy',
#  'bond length',
#  'bond lengths',
#  'bonding pressure',
#  'bonding temperature',
#  'box size',
#  'bp',
#  'bpa concentration',
#  'branching density',
#  'branching structures',
#  'break point frequency',
#  'breakdown',
#  'breakdown events range',
#  'breaking strain',
#  'breaking tensile strain',
#  'brightness enhancement factor',
#  'brightness levels',
#  'broad feature',
#  'broadening of glass transition peaks',
#  'broken',
#  'bromination yield',
#  'built-in voltage',
#  'bulk concentration',
#  'bulk enthalpy of crystallization',
#  'bulk glass transition temperature',
#  'bulk modulus',
#  'bulk swellability',
#  'bulk t_{g}',
#  'bulk tg',
#  'burning extent',
#  'butadiene content',
#  'byproduct',
#  'c',
#  'c 1s xps peak',
#  'c : p elemental ratio',
#  'c atomic percentage',
#  'c c bond peak',
#  'c c stretching bands',
#  'c content',
#  'c h bending',
#  'c h out-of-plane vibrations',
#  'c ips? o ips? c ether group absorption',
#  'c nmr',
#  'c nmr signal',
#  'c o bond peak',
#  'c o stretching vibration',
#  'c o stretching vibrations',
#  'c range',
#  'c t_{∞}',
#  "c'_h",
#  'c-c bond length',
#  'c-c bond length (double bond)',
#  'c-c bond length (single bond)',
#  'c-c separation',
#  'c-c single bond distance',
#  'c-h stretching aliphatic segments',
#  'c-h stretching vibrations',
#  'c-n bond stretching vibration',
#  'c-o bond length',
#  'c-o separation',
#  'c-o-c stretching of ether bond',
#  'c/n ratio',
#  'c/o atomic ratio',
#  'c1',
#  'c2',
#  'c=c bond length',
#  'c=o bond stretching vibration',
#  'c=o stretching',
#  'c=o stretching band (acetyl group)',
#  'c=o stretching band (carboxyl groups)',
#  'c_d+1',
#  'c_pabis',
#  'c_{3} h_{6} permeability',
#  'c_{3} h_{8} permeability',
#  'c_{e}',
#  'ca accumulation in tumors',
#  'ca concentration',
#  'ca/p molar ratio',
#  'calcd. p %',
#  'calcination temperature',
#  'calculated',
#  'calculated carbon weight percentage',
#  'calculated d-spacing',
#  'calculated hydrogen weight percentage',
#  'calculated mass',
#  'calculated molecular weight',
#  'calculated nitrogen weight percentage',
#  'calculated value of char residue at 700 ° c',
#  'calorimetric crystallinity',
#  'calorimetric melting temperature',
#  'capacitance per unit area',
#  'capacitances of the coatings',
#  'capacity loss',
#  'carbazole ring protons (4, 5-positions) peak',
#  'carbon consumption',
#  'carbon weight percentage',
#  'carbon yield at 900 °c',
#  'carbonate content',
#  'carbonate group content',
#  'carbonate linkage',
#  'carbonate selectivity',
#  'carbonyl absorption band',
#  'carbonyl absorption band (crystalline)',
#  'carbonyl absorption band (noncrystalline)',
#  'carbonyl peaks',
#  'carrier mobility',
#  'cas',
#  'catalysed',
#  'catalyst',
#  'catalyst activity',
#  'catalyst activity in ch_{2} cl_{2}',
#  'catalyst activity in toluene',
#  'catalyst amount',
#  'catalyst concentration',
#  'catalyst efficiency',
#  'catalyst l 1 zn',
#  'catalyst loading',
#  'catalyst system',
#  'catalysts',
#  'catalytic activity',
#  'catalytic activity in chloroform',
#  'catalytic activity in dichloromethane',
#  'catalytic activity in dioxolane',
#  'catalytic activity in toluene',
#  'catalytic efficiency',
#  'cathodic peak potential',
#  'cathodic peak wavelength',
#  'cathodic potential',
#  'cc distance',
#  'cd2+ adsorption efficiency',
#  'cdm',
#  'ce',
#  'ce at 1080 nm',
#  'ce at 500 nm',
#  'cell dimensions',
#  'cell distortion',
#  'cell killing',
#  'cell parameters',
#  'cell viability',
#  'cell viability',
#  'cell voltage',
#  'cellulose content',
#  'cellulose digestibility',
#  'centrifugation speed',
#  'ch3 rocking vibrations',
#  'ch4 diffusion coefficient',
#  'ch4 solubility coefficient',
#  'chain end structures',
#  'chain length',
#  'chain transfer constant',
#  'change in diffraction peak position',
#  'change in enthalpy',
#  'change in i_{pa}',
#  'change in peak position',
#  'change in storage modulus',
#  'change in t_{g}',
#  'change in torsional profile as a function of oligomer length',
#  'change in ρ',
#  'changes in m_{x}',
#  'char residue at 700 ° c',
#  'char yield at 600 °c',
#  'char yield at 700 °c',
#  'char yields at 800 °c',
#  'characteristic dielectric strength',
#  'characteristic length',
#  'characteristic molecular weight',
#  'characteristic ratio',
#  'characteristic ratio c_{∞}',
#  'characteristic timescale (faster process)',
#  'characteristic timescale (slower process)',
#  'characteristic wavelength',
#  'charcoal formation',
#  'charge',
#  'charge capacity',
#  'charge carrier mobility',
#  'charge for cooking',
#  'charge for monolayer adsorption of h_{2} on pt surfaces',
#  'charge mobility',
#  'charge ratio',
#  'charge transfer energy',
#  'charge transfer peak',
#  'chcl3-insoluble part',
#  'chemical compositions',
#  'chemical formula',
#  'chemical reactions temperature 1',
#  'chemical reactions temperature 2',
#  'chemical shift',
#  'chemical shift range',
#  'chemical shift reference',
#  'chemical shifts',
#  'chemical stability',
#  'chiral centers',
#  'chlorine content',
#  'chromophore concentration',
#  'chromophore concentrations',
#  'cie 1931 coordinates',
#  'cie coordinates change',
#  'cie values',
#  'cips 3/4o stretching band',
#  'cis',
#  'cis / trans in 1,4 structure',
#  'cis content',
#  'cl',
#  'cl content',
#  'clay content',
#  'cleaning solution',
#  'cleaning temperature',
#  'closest o⋯o distance',
#  'cm^{-1}',
#  'cmc',
#  'cmc',
#  'cn group absorption',
#  'cn stretching band',
#  'cnc content',
#  'co bond length',
#  'co distance',
#  'co-network',
#  'co-solvent composition',
#  'co2',
#  'co2/h2 selectivity',
#  'co2/n2 diffusion selectivity',
#  'co2/n2 selectivity',
#  'co2/n2 solubility selectivity',
#  'co_{2} permeability',
#  'co_{2}/ch_{4} ideal selectivity',
#  'co_{2}/ch_{4} selectivity',
#  'coating',
#  'coating capacitance',
#  'coating efficiency',
#  'coating impedance',
#  'coating level',
#  'coating temperature',
#  'coefficient',
#  'coefficient of correlation (r^2)',
#  'coefficient of thermal expansion',
#  'coercive force',
#  'coercivity',
#  'coherence length',
#  'cohesive energy',
#  'cold crystallisation exotherm',
#  'cold crystallization peak',
#  'cold crystallization point',
#  'color change',
#  'color coordinates',
#  'color coordinates (yxy)',
#  'color difference',
#  'color purity',
#  'color rendering index',
#  'color saturation',
#  'coloration efficiency (ce)',
#  'coloration rate',
#  'column dimensions',
#  'column length',
#  'column size',
#  'column temperature',
#  'combination of sec and maldi-tof mass spectrometry',
#  'commission internationale d-eclairage coordinates',
#  "commission internationale de l'eclairage 1931 coordinates",
#  'comonomer composition',
#  'comonomer feeding ratios',
#  'compare favorably',
#  'competitive capacity',
#  'completely cured resin',
#  'complex rate constant',
#  'complex viscosity',
#  'complexing abilities',
#  'composition',
#  'compositions',
#  'compression',
#  'compression stress',
#  'compressive strain',
#  'concentration factor',
#  'concentration in chlorobenzene',
#  'concentration of cnf',
#  'concentration of hq and cc',
#  'concentration of salt',
#  'concentration profile',
#  'concentration range',
#  'concentrations',
#  'conductance increase',
#  'conductivities',
#  'conductivity (dedoped)',
#  'conductivity (doped with fecl3)',
#  'conductivity (doped with i2)',
#  'conductivity (doped with nobf4)',
#  'conductivity (fecl3 doping)',
#  'conductivity contrast',
#  'conductivity response',
#  'conductivity values',
#  'conjugated fraction',
#  'conjugated pfa tg',
#  'conjugated polymer photovoltaic materials with broad absorption band and high charge carrier mobility',
#  'conjugated structure',
#  'consecutive cycles',
#  'consistency coefficient',
#  'constant',
#  'constant value',
#  'consumed',
#  'contact angle after grafting',
#  'contact angle at 25 °c',
#  'contact angle at 45 °c',
#  'contact angle at room temperature',
#  'contact angle before grafting',
#  'contact angle change',
#  'contact angle when heated',
#  'contact resistance (rc1)',
#  'contact resistivity',
#  'contact resistivity (rc2)',
#  'contamination',
#  'content',
#  'content of 1,4-repeating unit',
#  'content of h-units',
#  'content of methyl ester monomer unit',
#  'content of unreacted vinyl groups',
#  'content ratio',
#  'contents of daa-gptms',
#  'contents of hbn-oh',
#  'contrast',
#  'contribution ratio',
#  'contribution to climate warming',
#  'conv',
#  'conventional polymers',
#  'conversion',
#  'conversion efficiency',
#  'conversion of nbma',
#  'conversions',
#  'cooking liquor to fibre ratio',
#  'cooled to',
#  'cooling phase transition',
#  'cooling rate',
#  'cooling rates',
#  'coordination',
#  'coordination number',
#  'copolymer concentration',
#  'copolymerization ratio',
#  'copper concentration',
#  'core size',
#  'core-shell-corona micelles size',
#  'core/shell micelles size',
#  'correlation coefficient',
#  'corresponding enthalpy value of cold crystallization',
#  'corrosion current density',
#  'corrosion potential',
#  'cos',
#  'cost',
#  'coulombic efficiencies',
#  'counter-ion',
#  'cp',
#  'cp change',
#  'cr2+ adsorption efficiency',
#  'crack-onset strain',
#  'creep strain',
#  'cri value change',
#  'cri values',
#  'critical angle',
#  'critical conversion',
#  'critical exponent',
#  'critical forster distance',
#  'critical micelle concentration',
#  'critical micelle concentration (cmc)',
#  'critical molar fraction',
#  'critical molecular weight',
#  'critical mw',
#  'critical temperature',
#  'critical thickness',
#  'critical value',
#  'critical value χc',
#  'cross-head speed',
#  'cross-linking density',
#  'cross-linking efficiency',
#  'cross-sectional radius',
#  'crosslinked with 3% taic',
#  'crosslinking',
#  'crosslinking degrees',
#  'crosslinking temperature',
#  'crossover',
#  'crystal coherence length (ccl)',
#  'crystal lamellar thickness',
#  'crystal size',
#  'crystal sizes',
#  'crystal structure',
#  'crystalline degree',
#  'crystalline peak',
#  'crystalline polymer melting enthalpy',
#  'crystallinity after 32 weeks of degradation',
#  'crystallinity and tm changes onset temperature',
#  'crystallinity before degradation',
#  'crystallinity degree',
#  'crystallinity index',
#  'crystallinity levels',
#  'crystallisation temperature',
#  'crystallite size',
#  'crystallization',
#  'crystallization exotherm temperature',
#  'crystallization exothermal peak',
#  'crystallization exothermic peak temperature',
#  'crystallization kinetics',
#  'crystallization peak',
#  'crystallization peak temperature',
#  'crystallization transition',
#  'crystallization-rate maxima',
#  'cs+ counterions',
#  'csf concentration',
#  'ct band red shift',
#  'cta content',
#  'cta/initiator molar ratio',
#  'cte value',
#  'cte values',
#  'cu***cu distance',
#  'cu2+ adsorption efficiency',
#  'culture volume',
#  'cuo peak',
#  'cure temperature',
#  'cure temperatures',
#  'cure-temperature',
#  'curing peak temperature',
#  'current at 200 k',
#  'current at 250 k',
#  'current bump',
#  'current carrying capacity',
#  'current change',
#  'current enhancement',
#  'current increase',
#  'current increase voltage',
#  'current on/off ratio',
#  'current on/off ratios',
#  'current ratio',
#  'current response',
#  'current yield',
#  'cutoff',
#  'cutoff wavelength',
#  'cy value',
#  'cyanex 471x content',
#  'cycle',
#  'cycle number',
#  'cycles',
#  'cyclic stability',
#  'cycloadducts',
#  'cyclopropanation',
#  'cyclopropyl groups',
#  'd',
#  'd',
#  'd spacing',
#  'd t_{g}/d p',
#  'd values',
#  'd-content',
#  'd-d transition',
#  'd-lactide content',
#  'd-lactide content',
#  'd-spacing',
#  'd-spacing (d_l)',
#  'd-spacing (ip direction)',
#  'd-spacing (oop direction)',
#  'd-spacings',
#  'd/g ratio',
#  'd33',
#  'd_lamellar',
#  'd_spacing',
#  'd_{001}',
#  'd_{100}',
#  'd_{100} spacing',
#  'd_{33}',
#  'd_{iii} spacing',
#  'd_{i} spacing',
#  'd_π-π',
#  'da_{air}',
#  'da_{vacuum}',
#  'db',
#  'dbt concentration',
#  'dc conductivity',
#  'de',
#  'deacetylation',
#  'deacetylation temperature',
#  'deacetylation temperature (beta-chitin)',
#  'debye temperature',
#  'decomposition',
#  'decomposition constant',
#  'decomposition peak temperature',
#  'decomposition rate',
#  'decomposition start temperature',
#  'decomposition steps',
#  'decomposition stop temperature',
#  'decomposition temperature (5% weight-loss)',
#  'decomposition temperature (acid form)',
#  'decomposition temperature (sodium form)',
#  'decomposition temperature (t_{d})',
#  'decomposition temperature (t_{d}) at 5 % weight loss',
#  'decomposition temperature above',
#  'decomposition temperature at 10 % weight loss',
#  'decomposition temperature at 5 % weight loss',
#  'decomposition temperature at 5%',
#  'decomposition temperature at 5% weight loss (t5)',
#  'decomposition temperature increase',
#  'decomposition temperature range',
#  'decomposition temperatures',
#  'decrease',
#  'decrease in d_{eff}',
#  'decrease in discharge capacity',
#  'decrease in storage modulus temperature',
#  'decrease in t_{g}',
#  'decreased',
#  'dee',
#  'deflection',
#  'deflection measurement resolution',
#  'deformation at break',
#  'deformation temperature',
#  'deg content',
#  'degassing temperature',
#  'degradation',
#  'degradation of charge mobilities',
#  'degradation onset temperature',
#  'degradation product',
#  'degradation rate coefficient',
#  'degradation time',
#  'degree',
#  'degree in weight loss',
#  'degree of acetalization',
#  'degree of acetylation',
#  'degree of branching',
#  'degree of crosslinking',
#  'degree of crystallinity',
#  'degree of crystallization',
#  'degree of cure',
#  'degree of cyclization',
#  'degree of deacetylation',
#  'degree of grafting',
#  'degree of hydration',
#  'degree of hydrolysis',
#  'degree of modification',
#  'degree of neutralization',
#  'degree of polymerisation',
#  'degree of polymerization',
#  'degree of polymerization',
#  'degree of polymerization (dp)',
#  'degree of quaternization',
#  'degree of randomness',
#  'degree of saponification',
#  'degree of substitution',
#  'degree of sulfonation',
#  'degrees of crystallinity (xc)',
#  'degrees of polarization',
#  'degrees of polymerization',
#  'dendrimer',
#  'dendrimer-peg',
#  'density deviation from angelis et al',
#  ...]

# %%
# Extra unknown properties.
unknownprops = []
for prop in gprops:
    if prop not in propnames and prop not in knownprops:
        unknownprops.append(prop)

print("Properties that are not known, and extracted by the general pipeline:", len(unknownprops))
unknownprops
# Out:
# Properties that are not known, and extracted by the general pipeline: 4511
# ['%',
#  '% xylose rejection',
#  '% χ c',
#  '%de_{30}',
#  '%de_{90}',
#  '%i\\mu',
#  '(010) diffraction peak',
#  '(010) i-i stacking peak position',
#  '(010) scattering peak',
#  '(100) diffraction peaks',
#  '(100) scattering peak',
#  '(300) scattering peak',
#  '(dn/dc)μ',
#  '(oi)m',
#  '(δ m/ δ e)',
#  '(δ q/ δ e)',
#  '(τ_{ac} + τ_{br})',
#  '-(ch_{2}) n-protons of dodecyloxy group',
#  '-ch resonance',
#  '-och_{2} -groups attached to thiophene ring',
#  '-och_{2} ch_{2} peak',
#  '-so_{3} h absorption intensity',
#  '-δ s_{m}',
#  '0-0 absorption peak',
#  '0-0 transition',
#  '0-0 transition in film',
#  '0-0 transition in solution',
#  '0-1 absorption peak',
#  '0-2 absorption peak',
#  '1 % mass loss temperature',
#  '1 % weight loss temperature',
#  '1,4-cyclohexanedimethanol terephthalate content',
#  '1/ c_{1}',
#  '1/n',
#  '13c nmr',
#  '1^{31} p-nmr',
#  '1h nmr spectra',
#  '1h nmr spectrum',
#  '1hnmr',
#  '2,6-dfbn (mmol)',
#  '250 nm',
#  '2d flory exponent (v)',
#  '2θ',
#  '2θ angle',
#  '2θ d value',
#  '2θ scan data range',
#  '2θ value',
#  '2θ values',
#  "3-hydroxy-5-(4'-tolyl)valerate content",
#  '3-hydroxy-5-phenylvalerate content',
#  '3-hydroxyvalerate content',
#  '3ho content',
#  '4-mst moiety fraction',
#  '5 % weight loss temperature',
#  '5 % weight-loss temperature',
#  '5 wt % decomposition temperature (td5 %)',
#  '5 wt % loss temperature',
#  '5 wt % weight loss temperature',
#  '5% weight loss temperature (td5)',
#  '5% weight-loss temperature',
#  '50 % weight loss temperature',
#  '50 % weight-loss temperature',
#  '632 nm',
#  '< m_{n} >',
#  '< r^{2} > / m',
#  '<m_{n}>',
#  '<vh>',
#  '[1,4-dioxene]',
#  '[ibve-hcl]_3',
#  '[ibve-hcl]_{0}_{3}',
#  '[li]/[o]',
#  '[licl]/[bi] molar ratio',
#  '[licl]/[pbi] weight ratio',
#  '[m]/[i]',
#  '[m]/[i] ratio',
#  '[m]/[i] value',
#  '[mw/mn]',
#  '[pt-c]/[pbi] weight ratio',
#  '[η]^{a} (dl/g)',
#  '\\alpha',
#  '\\mu_{e}',
#  '^{13} c nmr',
#  '^{1} h nmr absorptions',
#  '^{1}^{13} c nmr signal',
#  '^{1}h nmr',
#  '^{1}h-nmr',
#  '^{31}p-nmr',
#  'a',
#  'a / a_{o} values',
#  'a b c',
#  'a_max',
#  'a_min',
#  'a_{m}',
#  'aa content',
#  'aa contents',
#  "abbe's number",
#  'abrasive size',
#  'absolute bioavailabilities',
#  'absolute bioavailability',
#  'absolute m_n',
#  'absolute molecular weight',
#  'absorbance',
#  'absorbance maximum (film)',
#  'absorbance peak',
#  'absorbance_band_1',
#  'absorbance_band_2',
#  'absorbed dose',
#  'absorbed doses',
#  'absorbed water content',
#  'absorbing n -aryl phenoxazine pcs',
#  'absorption',
#  'absorption band 1',
#  'absorption band 2',
#  'absorption band-edge',
#  'absorption bands (film)',
#  'absorption capacity',
#  'absorption characteristics',
#  'absorption coefficient at 550 nm',
#  'absorption coefficients',
#  'absorption edge (films)',
#  'absorption edge in solution',
#  'absorption edge in thin film',
#  'absorption edge of film',
#  'absorption increase',
#  'absorption maxima (film state)',
#  'absorption maxima (film)',
#  'absorption maxima (nmp solution)',
#  'absorption maxima (solid-state film)',
#  'absorption maxima (solution state)',
#  'absorption maxima (solution)',
#  'absorption maxima (λ_{max})',
#  'absorption maxima as a film',
#  'absorption maxima in chloroform solution',
#  'absorption maxima in film',
#  'absorption maxima in film state',
#  'absorption maxima in solid state',
#  'absorption maxima in solution',
#  'absorption maxima in thin films',
#  'absorption maximum (chloroform)',
#  'absorption maximum (film)',
#  'absorption maximum (ict band)',
#  'absorption maximum (π-π* transition band)',
#  'absorption maximum blue shift',
#  'absorption maximum in film',
#  'absorption maximum in thin film',
#  'absorption maximum peak',
#  'absorption onset wavelength',
#  'absorption onsets',
#  'absorption peak (dilute cb solution)',
#  'absorption peak (film)',
#  'absorption peak (long wavelength)',
#  'absorption peak (odcb solution)',
#  'absorption peak (short wavelength)',
#  'absorption peak (solution)',
#  'absorption peak (thin film)',
#  'absorption peak 1',
#  'absorption peak 2',
#  'absorption peak in film state',
#  'absorption peak in solution',
#  'absorption peak maxima in films',
#  'absorption peak maxima in solution',
#  'absorption peak wavelength',
#  'absorption peaks',
#  'absorption peaks (film)',
#  'absorption peaks (solid state)',
#  'absorption peaks (solution)',
#  'absorption peaks in chcl3 solution',
#  'absorption peaks in film state',
#  'absorption peaks in solid state',
#  'absorption peaks in thin film',
#  'absorption peaks in thin films',
#  'absorption redshift',
#  'absorption shoulder',
#  'absorption spectra broadening',
#  'absorption wavelength',
#  'absorption_band_1',
#  'absorption_band_2',
#  'absorption_edge',
#  'absorption_max',
#  'absorption_maxima',
#  'absorption_maxima_red_shift',
#  'absorption_peak_wavelength',
#  'absorptivity',
#  'acceleration voltage',
#  'acceptable stability profiles',
#  'accessibility efficacy of n active sites',
#  'accessible',
#  'accumulation of si on film surface',
#  'acetalization',
#  'acetalization level',
#  'acetone content',
#  'acetonitrile concentration',
#  'acetonitrile percentage',
#  'acidities',
#  'acidity threshold',
#  'acrylic acid content',
#  'acs (020)',
#  'acs (1 1 -0)',
#  'acs (110)',
#  'activation energy of curing reaction',
#  'activation energy of thermal decomposition',
#  'activation volume',
#  'active energy of decomposition (stage 1)',
#  'active energy of decomposition (stage 2)',
#  'active film thickness',
#  'active thickness',
#  'activity',
#  'ad',
#  'addition amount',
#  'additional absorption band',
#  'additional melting endotherm',
#  'additional relaxation',
#  'additional unique relaxations',
#  'additive concentration',
#  'additivity law',
#  'adhesion',
#  'adhesion pressure',
#  'adhesion strength',
#  'adhesive strength',
#  'adhesive strengths',
#  'adjusted to',
#  'adsorbed amount',
#  'adsorption capacity for atz',
#  'adsorption capacity for cd (ii)',
#  'adsorption capacity for dur',
#  'adsorption capacity for pb (ii)',
#  'adsorptions',
#  'after essay d',
#  'after essay mass',
#  'ag2---ag2* distance',
#  'agglomeration temperature',
#  'aggregation peak enthalpy',
#  'aggregation peak temperature',
#  'aging time',
#  'ag⋯ag distance',
#  'alkali resistance stability',
#  'alkoxy and n-alkyl side chain proton signals',
#  'alkylation yield',
#  'alkylphenoxy/phenoxy molar ratio',
#  'alpha r',
#  "alpha' transition temperature",
#  'alpha-cellulose',
#  'alpha-methyl peaks',
#  'alpha-methyl proton peaks',
#  'alpha-transition temperature',
#  'alpha_s/epsilon',
#  'am1.5g power conversion efficiency (pce)',
#  'amide bond absorption',
#  'amine content',
#  'amine equivalent weight',
#  'amino content',
#  'amino value',
#  'amorphous characteristics',
#  'amorphous content',
#  'amorphous phase',
#  'amorphous state',
#  'amount obtained',
#  'amount of agalo2 nps',
#  'amount of dead chains',
#  'amount of extractables',
#  'amount of fluorocarbon',
#  'amount of plasticizer',
#  'amount used in dsc measurements',
#  'amounts',
#  'amylose content',
#  'an concentration',
#  'an loads',
#  'anaerobic char yield',
#  'anatase content (ac)',
#  'angle',
#  'aniline concentration',
#  'anisotropic molecular polarizabilities',
#  'anisotropic molecular polarizability',
#  'anneal temperature',
#  'annealed',
#  'annealing',
#  'annealing time',
#  'annual increase rate',
#  'anodic current',
#  'anodic current of cc',
#  'anodic current of hq',
#  'anodic oxidation peak (first scan)',
#  'anodic oxidation peak (subsequent scans)',
#  'anodic oxidation peak current',
#  'anodic peak potential',
#  'anodic wave',
#  'anti-hiv',
#  'antibacterial activity',
#  'anticancer activity',
#  'antifungal activities against c. glabrata',
#  'antimicrobial',
#  'antisymmetric c c stretching',
#  'antitumor',
#  'apparent ea',
#  'apparent tg',
#  'appearance of ar-i',
#  'applied potential',
#  'applied potentials',
#  'approximate',
#  'aqueous solubility',
#  'area',
#  'area mass loading',
#  'area per chain',
#  'area per molecule',
#  'area under the stress-strain curve',
#  'aromatic',
#  'aromatic content',
#  'aromatic hydrogen resonance',
#  'aromatic resonance',
#  'ash content',
#  'aspect ratio',
#  'asymmetric stretching vibrations',
#  'at 600 °c',
#  'at amount',
#  'au accumulation in tumors',
#  'au concentration',
#  'auc_{0-2} h μg min/ml',
#  'average',
#  'average apparent thermal decomposition activation energies',
#  'average area per po monomeric unit',
#  'average degree of polymerization (dp)',
#  'average diameter',
#  'average diameter of microspheres',
#  'average diffusion coefficient',
#  'average electron mobility',
#  'average fet hole mobilities',
#  'average fiber diameter',
#  'average flux',
#  'average heating rate',
#  'average hole mobilities',
#  'average hole mobility',
#  'average hopping distance',
#  'average inter-ring angle',
#  'average inter-ring torsional angle',
#  'average length',
#  'average m_{n}',
#  'average mn',
#  'average mobilities',
#  'average mobility',
#  'average molar areas at full coverage',
#  'average molar areas at low coverage',
#  'average molar mass',
#  'average molecular mass',
#  'average molecular occupied surface area',
#  'average molecular weight',
#  'average molecular weight (_{w})',
#  'average molecular weight between crosslinks',
#  'average mw',
#  'average mw',
#  'average mw',
#  'average number molecular weight',
#  'average orientation of donor-and acceptor-dipoles',
#  'average particle size',
#  'average particles',
#  'average pce',
#  'average pore area',
#  'average pore size',
#  'average porosity',
#  'average potential for formation of doped state',
#  'average power conversion efficiency',
#  'average tg',
#  'average weight average molecular weight (m_{w})',
#  'average weight molar mass',
#  'average width',
#  'average-number molecular weight',
#  'averaged for analyses',
#  'avogadro number',
#  'avrami exponent',
#  'avrami exponent value',
#  'avrami index',
#  'avt',
#  'avts',
#  'axial resolution',
#  'azeotropic point',
#  'b',
#  'b',
#  'b value',
#  'ba content',
#  'back pressure',
#  'backbone bond length',
#  'bacterial count number',
#  'bake temperature',
#  'baking',
#  'baking temperature',
#  'balance',
#  'ball milling speed',
#  'ballistic cooling rate',
#  'band',
#  'band edge',
#  'band gap in film',
#  'band gap in thin film',
#  'bandgap interval',
#  'bands',
#  'barrier between the two minima at α ~ 90°',
#  'barrier to planarity at α ~ 135°',
#  'barrier to planarity at α ~ 30°',
#  'base pressure',
#  'based on',
#  'baseline concentration',
#  'bathochromic shift',
#  'bathochromic_shift',
#  'battery cracking',
#  'battery cycling',
#  'beads',
#  'bearing strength',
#  'benchmark values',
#  'benzene release',
#  'beta relaxation maxima',
#  'beta relaxation temperature',
#  'beta-transition temperature',
#  'between major and minor peaks',
#  'bias stress testing time',
#  'bias voltage',
#  'bif',
#  'bifp',
#  'binding energies',
#  'binding energy',
#  'bio-content',
#  'bioavailabilities',
#  'biodegraded',
#  'biomass',
#  'birefringence',
#  'bla',
#  'blend',
#  'blend component',
#  'blend composition',
#  'blend layer thickness',
#  'blend ratios',
#  'blended host',
#  'blended solution',
#  'blended with mdmo-ppv',
#  'blending temperature',
#  'block copolymerization',
#  'block size',
#  'blue emission peak shift',
#  'blue shift',
#  'blue-shift',
#  'boiling point',
#  'boiling-point',
#  'bond angle',
#  'bond angles',
#  'bond energy',
#  'bond length',
#  'bond lengths',
#  'bonding pressure',
#  'bonding temperature',
#  'box size',
#  'bp',
#  'bpa concentration',
#  'branching density',
#  'branching structures',
#  'break point frequency',
#  'breakdown',
#  'breakdown events range',
#  'breaking strain',
#  'breaking tensile strain',
#  'brightness enhancement factor',
#  'brightness levels',
#  'broad feature',
#  'broadening of glass transition peaks',
#  'broken',
#  'bromination yield',
#  'built-in voltage',
#  'bulk concentration',
#  'bulk enthalpy of crystallization',
#  'bulk modulus',
#  'bulk swellability',
#  'bulk t_{g}',
#  'bulk tg',
#  'burning extent',
#  'butadiene content',
#  'byproduct',
#  'c',
#  'c 1s xps peak',
#  'c : p elemental ratio',
#  'c atomic percentage',
#  'c c bond peak',
#  'c c stretching bands',
#  'c content',
#  'c h bending',
#  'c h out-of-plane vibrations',
#  'c ips? o ips? c ether group absorption',
#  'c nmr',
#  'c nmr signal',
#  'c o bond peak',
#  'c o stretching vibration',
#  'c o stretching vibrations',
#  'c range',
#  'c t_{∞}',
#  "c'_h",
#  'c-c bond length',
#  'c-c bond length (double bond)',
#  'c-c bond length (single bond)',
#  'c-c separation',
#  'c-c single bond distance',
#  'c-h stretching aliphatic segments',
#  'c-h stretching vibrations',
#  'c-n bond stretching vibration',
#  'c-o bond length',
#  'c-o separation',
#  'c-o-c stretching of ether bond',
#  'c/n ratio',
#  'c/o atomic ratio',
#  'c1',
#  'c2',
#  'c=c bond length',
#  'c=o bond stretching vibration',
#  'c=o stretching',
#  'c=o stretching band (acetyl group)',
#  'c=o stretching band (carboxyl groups)',
#  'c_d+1',
#  'c_pabis',
#  'c_{3} h_{6} permeability',
#  'c_{3} h_{8} permeability',
#  'c_{e}',
#  'ca accumulation in tumors',
#  'ca concentration',
#  'ca/p molar ratio',
#  'calcd. p %',
#  'calcination temperature',
#  'calculated',
#  'calculated carbon weight percentage',
#  'calculated d-spacing',
#  'calculated hydrogen weight percentage',
#  'calculated mass',
#  'calculated nitrogen weight percentage',
#  'calculated value of char residue at 700 ° c',
#  'calorimetric melting temperature',
#  'capacitance per unit area',
#  'capacitances of the coatings',
#  'capacity loss',
#  'carbazole ring protons (4, 5-positions) peak',
#  'carbon consumption',
#  'carbon weight percentage',
#  'carbon yield at 900 °c',
#  'carbonate content',
#  'carbonate group content',
#  'carbonate linkage',
#  'carbonate selectivity',
#  'carbonyl absorption band',
#  'carbonyl absorption band (crystalline)',
#  'carbonyl absorption band (noncrystalline)',
#  'carbonyl peaks',
#  'carrier mobility',
#  'cas',
#  'catalysed',
#  'catalyst',
#  'catalyst activity',
#  'catalyst activity in ch_{2} cl_{2}',
#  'catalyst activity in toluene',
#  'catalyst amount',
#  'catalyst concentration',
#  'catalyst efficiency',
#  'catalyst l 1 zn',
#  'catalyst loading',
#  'catalyst system',
#  'catalysts',
#  'catalytic activity',
#  'catalytic activity in chloroform',
#  'catalytic activity in dichloromethane',
#  'catalytic activity in dioxolane',
#  'catalytic activity in toluene',
#  'catalytic efficiency',
#  'cathodic peak potential',
#  'cathodic peak wavelength',
#  'cathodic potential',
#  'cc distance',
#  'cd2+ adsorption efficiency',
#  'cdm',
#  'ce',
#  'ce at 1080 nm',
#  'ce at 500 nm',
#  'cell dimensions',
#  'cell distortion',
#  'cell killing',
#  'cell parameters',
#  'cell viability',
#  'cell viability',
#  'cell voltage',
#  'cellulose content',
#  'cellulose digestibility',
#  'centrifugation speed',
#  'ch3 rocking vibrations',
#  'ch4 diffusion coefficient',
#  'ch4 solubility coefficient',
#  'chain end structures',
#  'chain length',
#  'chain transfer constant',
#  'change in diffraction peak position',
#  'change in enthalpy',
#  'change in i_{pa}',
#  'change in peak position',
#  'change in storage modulus',
#  'change in t_{g}',
#  'change in torsional profile as a function of oligomer length',
#  'change in ρ',
#  'changes in m_{x}',
#  'char residue at 700 ° c',
#  'char yield at 600 °c',
#  'char yield at 700 °c',
#  'char yields at 800 °c',
#  'characteristic dielectric strength',
#  'characteristic length',
#  'characteristic molecular weight',
#  'characteristic ratio',
#  'characteristic ratio c_{∞}',
#  'characteristic timescale (faster process)',
#  'characteristic timescale (slower process)',
#  'characteristic wavelength',
#  'charcoal formation',
#  'charge',
#  'charge capacity',
#  'charge carrier mobility',
#  'charge for cooking',
#  'charge for monolayer adsorption of h_{2} on pt surfaces',
#  'charge mobility',
#  'charge ratio',
#  'charge transfer energy',
#  'charge transfer peak',
#  'chcl3-insoluble part',
#  'chemical compositions',
#  'chemical formula',
#  'chemical reactions temperature 1',
#  'chemical reactions temperature 2',
#  'chemical shift',
#  'chemical shift range',
#  'chemical shift reference',
#  'chemical shifts',
#  'chemical stability',
#  'chiral centers',
#  'chlorine content',
#  'chromophore concentration',
#  'chromophore concentrations',
#  'cie 1931 coordinates',
#  'cie coordinates change',
#  'cie values',
#  'cips 3/4o stretching band',
#  'cis',
#  'cis / trans in 1,4 structure',
#  'cis content',
#  'cl',
#  'cl content',
#  'clay content',
#  'cleaning solution',
#  'cleaning temperature',
#  'closest o⋯o distance',
#  'cm^{-1}',
#  'cmc',
#  'cmc',
#  'cn group absorption',
#  'cn stretching band',
#  'cnc content',
#  'co bond length',
#  'co distance',
#  'co-network',
#  'co-solvent composition',
#  'co2',
#  'co2/h2 selectivity',
#  'co2/n2 diffusion selectivity',
#  'co2/n2 solubility selectivity',
#  'co_{2}/ch_{4} ideal selectivity',
#  'coating',
#  'coating capacitance',
#  'coating efficiency',
#  'coating impedance',
#  'coating level',
#  'coating temperature',
#  'coefficient',
#  'coefficient of correlation (r^2)',
#  'coefficient of thermal expansion',
#  'coercive force',
#  'coercivity',
#  'coherence length',
#  'cohesive energy',
#  'cold crystallisation exotherm',
#  'cold crystallization peak',
#  'cold crystallization point',
#  'color change',
#  'color coordinates',
#  'color coordinates (yxy)',
#  'color difference',
#  'color purity',
#  'color rendering index',
#  'color saturation',
#  'coloration efficiency (ce)',
#  'coloration rate',
#  'column dimensions',
#  'column length',
#  'column size',
#  'column temperature',
#  'combination of sec and maldi-tof mass spectrometry',
#  'commission internationale d-eclairage coordinates',
#  "commission internationale de l'eclairage 1931 coordinates",
#  'comonomer composition',
#  'comonomer feeding ratios',
#  'compare favorably',
#  'competitive capacity',
#  'completely cured resin',
#  'complex rate constant',
#  'complex viscosity',
#  'complexing abilities',
#  'composition',
#  'compositions',
#  'compression',
#  'compression stress',
#  'compressive strain',
#  'concentration factor',
#  'concentration in chlorobenzene',
#  'concentration of cnf',
#  'concentration of hq and cc',
#  'concentration of salt',
#  'concentration profile',
#  'concentration range',
#  'concentrations',
#  'conductance increase',
#  'conductivities',
#  'conductivity (dedoped)',
#  'conductivity (doped with fecl3)',
#  'conductivity (doped with i2)',
#  'conductivity (doped with nobf4)',
#  'conductivity (fecl3 doping)',
#  'conductivity contrast',
#  'conductivity response',
#  'conductivity values',
#  'conjugated fraction',
#  'conjugated pfa tg',
#  'conjugated polymer photovoltaic materials with broad absorption band and high charge carrier mobility',
#  'conjugated structure',
#  'consecutive cycles',
#  'consistency coefficient',
#  'constant',
#  'constant value',
#  'consumed',
#  'contact angle after grafting',
#  'contact angle at 25 °c',
#  'contact angle at 45 °c',
#  'contact angle at room temperature',
#  'contact angle before grafting',
#  'contact angle change',
#  'contact angle when heated',
#  'contact resistance (rc1)',
#  'contact resistivity',
#  'contact resistivity (rc2)',
#  'contamination',
#  'content',
#  'content of 1,4-repeating unit',
#  'content of h-units',
#  'content of methyl ester monomer unit',
#  'content of unreacted vinyl groups',
#  'content ratio',
#  'contents of daa-gptms',
#  'contents of hbn-oh',
#  'contrast',
#  'contribution ratio',
#  'contribution to climate warming',
#  'conv',
#  'conventional polymers',
#  'conversion',
#  'conversion efficiency',
#  'conversion of nbma',
#  'conversions',
#  'cooking liquor to fibre ratio',
#  'cooled to',
#  'cooling phase transition',
#  'cooling rate',
#  'cooling rates',
#  'coordination',
#  'coordination number',
#  'copolymer concentration',
#  'copolymerization ratio',
#  'copper concentration',
#  'core size',
#  'core-shell-corona micelles size',
#  'core/shell micelles size',
#  'correlation coefficient',
#  'corresponding enthalpy value of cold crystallization',
#  'corrosion current density',
#  'corrosion potential',
#  'cos',
#  'cost',
#  'coulombic efficiencies',
#  'counter-ion',
#  'cp',
#  'cp change',
#  'cr2+ adsorption efficiency',
#  'crack-onset strain',
#  'creep strain',
#  'cri value change',
#  'cri values',
#  'critical angle',
#  'critical conversion',
#  'critical exponent',
#  'critical forster distance',
#  'critical micelle concentration',
#  'critical micelle concentration (cmc)',
#  'critical molar fraction',
#  'critical molecular weight',
#  'critical mw',
#  'critical temperature',
#  'critical thickness',
#  'critical value',
#  'critical value χc',
#  'cross-head speed',
#  'cross-linking density',
#  'cross-linking efficiency',
#  'cross-sectional radius',
#  'crosslinked with 3% taic',
#  'crosslinking',
#  'crosslinking degrees',
#  'crosslinking temperature',
#  'crossover',
#  'crystal coherence length (ccl)',
#  'crystal lamellar thickness',
#  'crystal size',
#  'crystal sizes',
#  'crystal structure',
#  'crystalline degree',
#  'crystalline peak',
#  'crystalline polymer melting enthalpy',
#  'crystallinity after 32 weeks of degradation',
#  'crystallinity and tm changes onset temperature',
#  'crystallinity before degradation',
#  'crystallisation temperature',
#  'crystallite size',
#  'crystallization',
#  'crystallization exotherm temperature',
#  'crystallization exothermal peak',
#  'crystallization exothermic peak temperature',
#  'crystallization kinetics',
#  'crystallization peak',
#  'crystallization peak temperature',
#  'crystallization transition',
#  'crystallization-rate maxima',
#  'cs+ counterions',
#  'csf concentration',
#  'ct band red shift',
#  'cta content',
#  'cta/initiator molar ratio',
#  'cte value',
#  'cte values',
#  'cu***cu distance',
#  'cu2+ adsorption efficiency',
#  'culture volume',
#  'cuo peak',
#  'cure temperature',
#  'cure temperatures',
#  'cure-temperature',
#  'curing peak temperature',
#  'current at 200 k',
#  'current at 250 k',
#  'current bump',
#  'current carrying capacity',
#  'current change',
#  'current enhancement',
#  'current increase',
#  'current increase voltage',
#  'current on/off ratio',
#  'current on/off ratios',
#  'current ratio',
#  'current response',
#  'current yield',
#  'cutoff',
#  'cutoff wavelength',
#  'cy value',
#  'cyanex 471x content',
#  'cycle',
#  'cycle number',
#  'cycles',
#  'cyclic stability',
#  'cycloadducts',
#  'cyclopropanation',
#  'cyclopropyl groups',
#  'd',
#  'd',
#  'd spacing',
#  'd t_{g}/d p',
#  'd values',
#  'd-content',
#  'd-d transition',
#  'd-lactide content',
#  'd-lactide content',
#  'd-spacing',
#  'd-spacing (d_l)',
#  'd-spacing (ip direction)',
#  'd-spacing (oop direction)',
#  'd-spacings',
#  'd/g ratio',
#  'd33',
#  'd_lamellar',
#  'd_spacing',
#  'd_{001}',
#  'd_{100}',
#  'd_{100} spacing',
#  'd_{33}',
#  'd_{iii} spacing',
#  'd_{i} spacing',
#  'd_π-π',
#  'da_{air}',
#  'da_{vacuum}',
#  'db',
#  'dbt concentration',
#  'dc conductivity',
#  'de',
#  'deacetylation',
#  'deacetylation temperature',
#  'deacetylation temperature (beta-chitin)',
#  'debye temperature',
#  'decomposition',
#  'decomposition constant',
#  'decomposition peak temperature',
#  'decomposition rate',
#  'decomposition start temperature',
#  'decomposition steps',
#  'decomposition stop temperature',
#  'decomposition temperature (5% weight-loss)',
#  'decomposition temperature (acid form)',
#  'decomposition temperature (sodium form)',
#  'decomposition temperature (t_{d})',
#  'decomposition temperature (t_{d}) at 5 % weight loss',
#  'decomposition temperature above',
#  'decomposition temperature at 10 % weight loss',
#  'decomposition temperature at 5 % weight loss',
#  'decomposition temperature at 5%',
#  'decomposition temperature at 5% weight loss (t5)',
#  'decomposition temperature increase',
#  'decomposition temperature range',
#  'decrease',
#  'decrease in d_{eff}',
#  'decrease in discharge capacity',
#  'decrease in storage modulus temperature',
#  'decrease in t_{g}',
#  'decreased',
#  'dee',
#  'deflection',
#  'deflection measurement resolution',
#  'deformation at break',
#  'deformation temperature',
#  'deg content',
#  'degassing temperature',
#  'degradation',
#  'degradation of charge mobilities',
#  'degradation onset temperature',
#  'degradation product',
#  'degradation rate coefficient',
#  'degradation time',
#  'degree',
#  'degree in weight loss',
#  'degree of acetalization',
#  'degree of acetylation',
#  'degree of branching',
#  'degree of crosslinking',
#  'degree of crystallization',
#  'degree of cure',
#  'degree of cyclization',
#  'degree of deacetylation',
#  'degree of grafting',
#  'degree of hydration',
#  'degree of hydrolysis',
#  'degree of modification',
#  'degree of neutralization',
#  'degree of polymerisation',
#  'degree of polymerization',
#  'degree of polymerization',
#  'degree of polymerization (dp)',
#  'degree of quaternization',
#  'degree of randomness',
#  'degree of saponification',
#  'degree of substitution',
#  'degree of sulfonation',
#  'degrees of polarization',
#  'degrees of polymerization',
#  'dendrimer',
#  'dendrimer-peg',
#  'density deviation from angelis et al',
#  'density distribution of interface states',
#  'density of dislocations',
#  'density of hydroxyls',
#  'density of states at the fermi level',
#  'density of the polymers',
#  'deposit loss',
#  'deposition pressure',
#  'deposition rate',
#  'deposition temperature',
#  'deposition time',
#  'desirability',
#  'desorption',
#  'desorption time',
#  'detection range',
#  'development of novel conjugated donor polymers for high efficiency bulk heterojunction photovoltaic devices',
#  'deviation',
#  'device performance',
#  'devices',
#  'dhns: biphenol ratio',
#  'dhtp content',
#  'di',
#  'diameter of holes',
#  'diameters',
#  'diameters of hollow microspheres',
#  'diamine incorporation',
#  'dielectric characteristics',
#  ...]
